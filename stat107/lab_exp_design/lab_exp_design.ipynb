# %% [markdown]
# # Welcome to Lab: Experimental Design 👨‍🔬⚗️🧪
#
# Before this lab section, you completed the "Hello Survey" based on the questions you generated with your groups.  This week, you will do an analysis of the results and explore techniques to do great experimental design in Python!
#
# A few tips to remember:
#
# - **You are not alone on your journey in learning programming!**  You have your lab Teaching Assistant, your Course Aides, your lab group, and the professors (Prof. Wade and Prof. Karle), who are all here to help you out!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %% [markdown]
# <hr style="color: #DD3403;">

# %%
# Meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "Arghya"
ca1_name = "Salar"
ca2_name = "Sri"


# Say hello to each other!
# - Groups of 3 are ideal :)
# - However groups of 2 or 4 are fine too!
partner1_name = "Om"
partner1_netid = "opate20"
partner1_inYourGroupLastWeek = "yes"

partner2_name = "Justin"
partner2_netid = "jnovo2"
partner1_inYourGroupLastWeek = "yes"

partner3_name = "Victor"
partner3_netid = "vsamu2"
partner1_inYourGroupLastWeek = "yes"

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: Hello Dataset Analysis
#
# In lab last week, you created a series of questions that made up the **"Hello Dataset"**.  Before lab, you completed this survey along with the entire course.  Today, you're going to do analysis on this dataset! :)

# %% [markdown]
# ## Your Binary Question Analysis
#
# You will be analyzing the **binary question** your group asked the class from `lab_pandas` -- record it below.  If multiple people from your group had different binary questions, decide which one to use and record that question below.

# %% [markdown]
# What season do you prefer, fall or spring?

# %% [markdown]
# ## Load the Hello Dataset
#
# The "Hello Dataset" is available here:
# ```
# https://waf.cs.illinois.edu/discovery/hello-fa23.csv
# ```
#
# Use Python to load this dataset into a DataFrame called `df`. Don't forget to import pandas as well!

# %%
import pandas as pd
df = pd.read_csv("https://waf.cs.illinois.edu/discovery/hello-fa23.csv")
df
# Out:
#                        Name Section  \
# 0               Prof. Karle  L1, L2
# 1                Prof. Wade  L1, L2
# 2                    Andrew     Y05
# 3                  Annabel      Y05
# 4                    Ayden      Y14
# ..                      ...     ...
# 960  Mohammed Fatheen Ahmed     Y22
# 961                   Peter     Y09
# 962                   Nyssa     Y23
# 963                  maddax      Y2
# 964              CA Sangjun     Y23
#
#     Does your NetID ending with odd number or even number?  \
# 0                        NetID ends with an odd number
# 1                                                  NaN
# 2                        NetID ends with an odd number
# 3                       NetID ends with an even number
# 4                       NetID ends with an even number
# ..                                                 ...
# 960                      NetID ends with an odd number
# 961                     NetID ends with an even number
# 962                      NetID ends with an odd number
# 963                      NetID ends with an odd number
# 964                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 0                                                Heads
# 1                                                Heads
# 2                                                Heads
# 3                                                Heads
# 4                                                Heads
# ..                                                 ...
# 960                                              Heads
# 961                                              Heads
# 962                                              Heads
# 963                                              Tails
# 964                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 0                                 Tacos                    0.0
# 1                                 Tacos                    1.0
# 2                                 Tacos                    1.0
# 3                                 Tacos                    0.0
# 4                                Donuts                    1.0
# ..                                  ...                    ...
# 960                              Donuts                    0.0
# 961                               Tacos                    1.0
# 962                               Tacos                    1.0
# 963                               Tacos                    0.0
# 964                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 0                   Not a Freshman                         Night Person
# 1                   Not a Freshman                         Night Person
# 2              Freshman in College                         Night Person
# 3                   Not a Freshman                         Night Person
# 4              Freshman in College                         Night Person
# ..                             ...                                  ...
# 960            Freshman in College                       Morning Person
# 961                 Not a Freshman                       Morning Person
# 962            Freshman in College                         Night Person
# 963            Freshman in College                         Night Person
# 964                 Not a Freshman                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 0                            Afternoon Person
# 1                            Afternoon Person
# 2                            Afternoon Person
# 3                            Afternoon Person
# 4                              Morning Person
# ..                                        ...
# 960                            Morning Person
# 961                            Morning Person
# 962                          Afternoon Person
# 963                          Afternoon Person
# 964                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 0                                           Illinois  ...
# 1                                                NaN  ...
# 2                                       Out-of-state  ...
# 3                                           Illinois  ...
# 4                                           Illinois  ...
# ..                                               ...  ...
# 960                                         Illinois  ...
# 961                                     Out-of-state  ...
# 962                                         Illinois  ...
# 963                                         Illinois  ...
# 964                                     Out-of-state  ...
#
#     From 1 to 10, how happy are you right now?  \
# 0                                         9.00
# 1                                         8.25
# 2                                         7.00
# 3                                         5.00
# 4                                         8.00
# ..                                         ...
# 960                                       3.00
# 961                                       5.00
# 962                                       8.00
# 963                                       1.00
# 964                                       8.00
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 0                                             moderate
# 1                                             Moderate
# 2                                             moderate
# 3                                             Moderate
# 4                                               Strong
# ..                                                 ...
# 960                                             strong
# 961                                             strong
# 962                                               mild
# 963                                            extreme
# 964                                               Mild
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 0                                           Statistics
# 1                                             Grainger
# 2                                                  LAS
# 3                                     ISchool and LAS
# 4                                                 Gies
# ..                                                 ...
# 960                                                las
# 961                                                 CS
# 962                                                las
# 963                          finance with data science
# 964                                         Statistics
#
#     What do you think is the hardest major at UIUC?  \
# 0                             Anything in GRAINGER!
# 1                                           Physics
# 2                                                CS
# 3                                 Computer science
# 4                                   Any engineering
# ..                                              ...
# 960                                              CS
# 961                                              CS
# 962                                             ece
# 963                                         general
# 964                                     Engineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 0                           TAYLOR SWIFT!                       Taylor Swift
# 1                             Pop and EDM                       Taylor Swift
# 2                                     rap                               Dave
# 3                              Rap or r&b                            Eminem
# 4                               Indie pop                      The Lumineers
# ..                                    ...                                ...
# 960                                   rap                              Drake
# 961                                  Jazz                                 Ye
# 962                                   pop                       taylor swift
# 963                                   rap                       lil uzi vert
# 964                                   RnB                      Wave to Earth
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 0                                Instagram                        I-N-I
# 1                                  YouTube                        I-N-I
# 2                                instagram                        I-N-I
# 3                                Snapchat                           INI
# 4                                 Snapchat                          INI
# ..                                     ...                          ...
# 960                                   Snap                         ini
# 961                                     QQ                         illi
# 962                                twitter                          INI
# 963                               snapchat                          ini
# 964                              Instagram                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 0                                Any type of card game
# 1                                             Factorio
# 2                                               soccer
# 3                             Volleyball or fortnight
# 4                                           Basketball
# ..                                                 ...
# 960                                       apex legends
# 961                                     Clash of clans
# 962                                         code names
# 963                                        quiet game
# 964                                     Clash of Clans
#
#     What is your dream vacation location?
# 0                            The Maldives
# 1                               Mountains
# 2                                  Hawaii
# 3                                 Greece
# 4                              Australia
# ..                                    ...
# 960                                europe
# 961                               Iceland
# 962                                greece
# 963                    middle of nowhere
# 964                                 Korea
#
# [965 rows x 178 columns]

# %% [markdown]
# ## Find The Variable for Your Question
#
# The command `df.columns.tolist()` will **list all of the columns (variables)** in a DataFrame.  Use `df.columns.tolist()` and read the output until you find the column name for your binary question.
#
# - You may see the message: `Output exceeds the __size limit__. Open the full output data __in a text editor__`
# - If you do, click the **`__in a text editor__`** link to open the whole list in a new tab. :)

# %%
df.columns.tolist()
# Out:
# ['Name',
#  'Section',
#  'Does your NetID ending with odd number or even number?',
#  'If I flipped a coin, do you think it would it land on heads or tails?',
#  'Do you like to eat tacos or donuts?',
#  'Pick a Number: 0 or 1',
#  'Are you a freshman in college?',
#  'Are you a morning or a night person?',
#  'Are you a morning or an afternoon person?',
#  'Are you a student from Illinois or out-of-state?',
#  'Are you a student in Grainger?',
#  'Are you a Taylor Swift fan?',
#  'Are you a winter or summer person?',
#  'Are you above or equal to 5 foot 6 inches?',
#  'Are you an early bird or night owl?',
#  'Are you an extrovert or an introvert?',
#  'Are you an international student or from the United States?',
#  'Are you an underclassmen or lowerclassmen?',
#  'Is the day of the month of your birth even or odd?  (Ex: May 28 is even, but June 3 is odd)',
#  'Are you from the Chicago suburbs?',
#  'Are you in LAS?',
#  'Are you in the 9:00 AM or 11:00 AM DISCOVERY lecture?',
#  'Are you involved/will be involved in Greek life?',
#  'Are you living on or off campus?',
#  'Do you identify as a male or female?',
#  'Are you older than 18?',
#  'Are you sitting in a light or dark colored chair?',
#  'Are you the first person from your entire family to attend University of Illinois?',
#  'Are you wearing glasses right now?',
#  'Are your parents immigrants?',
#  'Beef or Chicken?',
#  'Chocolate or Vanilla?',
#  'Coffee or Tea?',
#  'Coke or Pepsi? ',
#  'Did you attend lecture on Friday?',
#  'Did you grow up in the Midwest?',
#  'Did you move in from the 13-16th or the 17-20th?',
#  'Did you sit on the left or the right side of the hall during the last lecture?',
#  'Do you consider a cup to be half empty or half full?',
#  'Do you dance?',
#  'Do you drink black coffee?',
#  'Do you drink coffee every day?',
#  'Do you eat breakfast in the morning?',
#  'Do you grow up in Illinois?',
#  'Do you hang your toilet paper over or under?',
#  'Do you have an iPhone?',
#  'Do you have an odd or even amount of letters in your first name?',
#  'Do you have any siblings?',
#  'Do you have black hair or non-black hair?',
#  'Do you have brown eyes or any other color?',
#  'Do you have short hair or long hair?',
#  'Do you have your Data Science Discovery lab section on Wednesday or after Wednesday?',
#  'Do you have your ears pierced?',
#  'Do you introduce yourself to a new person using "hi" or "hello"?',
#  'Do you like C++ or Java?',
#  'Do you like Chinese food?',
#  'Do you like dogs or cats?',
#  'Do you like football or basketball better?',
#  'Do you like ice cream?',
#  'Do you like orange juice or apple juice?',
#  'Do you like pancakes or waffles?',
#  'Pink or Blue?',
#  'Pizza or a burger?',
#  'Pizza or pasta?',
#  'Summer or Winter?',
#  'Do you like to wear hats?',
#  'Do you like UIUC?',
#  'Do you listen to music on the way to classes?',
#  'Do you live in a residence hall or private housing?',
#  'Do you prefer Nike or Adidas for shoes?',
#  'Do you prefer vanilla or chocolate ice cream? ',
#  'Burger or Taco?',
#  'Do you prefer American Football or Cricket?',
#  'Do you prefer apples or bananas?',
#  'Do you prefer blue or orange? ',
#  'Do you prefer blue or pink?',
#  'Do you prefer chipmunks or squirrels?',
#  'Do you prefer Coke or Sprite? ',
#  'Do you prefer cold drinks or hot drinks?',
#  'Do you prefer cold or hot weather?',
#  'Do you prefer crinkle-cut or straight-cut fries?',
#  'Do you prefer earbuds or headphones?',
#  'Do you prefer fall or spring?',
#  'Do you prefer fall or summer?',
#  'Do you prefer green or red?',
#  'Do you prefer Hot Cheetos or Takis?',
#  'Do you prefer Hot Coffee or Ice Coffee?',
#  'Do you prefer hot or iced tea?',
#  'Do you prefer hotdogs or burgers?',
#  'Do you prefer ketchup or ranch?',
#  'Do you prefer Mac or Windows?',
#  'Do you prefer Marvel or DC comics?',
#  'Do you prefer movies or TV shows?',
#  'Do you prefer online class or in-person class?',
#  'Pizza or tacos?',
#  'Do you prefer red or blue?',
#  'Do you prefer regular or diet soda?',
#  'Do you prefer Soccer or American Football?',
#  'Do you prefer spend your time outdoor or indoor?',
#  'Superman or batman?',
#  'Do you prefer sweet or salty foods?',
#  'Do you prefer sweet or savory food?',
#  'Do you prefer sweet or sour foods?',
#  'Do you prefer the color YELLOW or the color ORANGE?',
#  'Do you prefer the letter "M" or "N"?',
#  'Do you prefer the number 3 or the number 4?',
#  'Do you prefer to eat at ISR or IKE?',
#  'Do you prefer to have pets or no pets?',
#  'Do you prefer to listen to audio through headphones or speakers?',
#  'Do you prefer to shower at night or in the morning?',
#  'Do you prefer vegetables or fruit?',
#  'Do you pronounce caramel as "care-a-mel" or "car-mel"?',
#  'Do you pronounce Illinois "Ill-uh-noise" or "Ill-uh-noy"?',
#  'Do you pronounce the word "data" like "dah-tah" or "day-tah?"',
#  'Do you put ketchup on your hotdog?',
#  'Do you speak a language other than English?',
#  'Do you think there are more doors or wheels in the world?',
#  'Do you use Spotify or Apple Music?',
#  'Do you walk to class?',
#  'Do you wear glasses or contacts?',
#  'Does pineapple belong on pizza?',
#  'Does your first name start with a letter between A-M? (including A and M)?',
#  'Does your last name start with any letter between "A" through "L" or "M" through "Z"?',
#  'Does your UIN end with an even number or an odd number? (0 is considered an even number)',
#  'Folklore or Evermore?',
#  'Have you traveled outside of the USA this summer?',
#  'Have you ever traveled outside the USA?',
#  'Is a hotdog a sandwich?',
#  'Is math red or blue?',
#  'Is the last digit of your phone number even?',
#  'Is water wet?',
#  'Is your age an even number or an odd number?',
#  'Is your month of your birth odd or even?',
#  'Is your birthday before/on or after July 1st?',
#  'Is your day good or bad?',
#  'Is your dorm/apartment room number even?',
#  'Is your favorite color blue?',
#  'Is your favorite number even?',
#  'Is your major STEM or a humanity?',
#  'Lebron or Jordan?',
#  'Popeyes or KFC?',
#  'Was UIUC your first choice school when applying for college? ',
#  'Were you born before Feb. 14, 2005?',
#  'What came first, the chicken or the egg?',
#  'Which is the better ice cream flavor: chocolate chip or vanilla?',
#  'Which movie do you prefer Barbie or Oppenheimer?',
#  'Which number do you prefer: 49 or 62?',
#  'Which Ryan is better, Ryan Gosling or Ryan Reynolds?',
#  'which sequence do you prefer more tbge5 or pbt2l?',
#  'Who would win in a fight, Cinderella or Snow White?',
#  'Would you choose Mexican or Italian food?',
#  'Would you prefer to live an urban or rural life?',
#  'Would you rather get a book about your past or a letter revealing something about your future?',
#  'Would you rather go to an amusement park or beach?',
#  'Would you rather have a personal theme song that plays every time you enter a room, or have a spotlight follow you everywhere you go?',
#  'Would you rather have hiccups for the rest of your life or constantly feel like you have to sneeze?',
#  'Would you rather know how you die or when you die?',
#  'Would you rather never use a phone or computer again?',
#  'Would you rather take notes on a computer/tablet or paper?',
#  'In terms of Data Science, do you prefer statistics or computer science?',
#  'How many classes are you taking this semester?',
#  'How many credit hours are you taking?',
#  'How many hours do you sleep in a day?',
#  'How many siblings do you have?',
#  'What is your phone battery percentage currently at?',
#  'How many people is the ideal number of people at a party?',
#  'What is the lowest numbered course you are taking this semester?',
#  'What is your shoe size (US size)?',
#  'From 1 to 10, how happy are you right now?',
#  "The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?",
#  'What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)',
#  'What do you think is the hardest major at UIUC?',
#  'What genre of music do you listen to?',
#  'Who is your favorite music artist?',
#  "What's your favorite social media app?",
#  'How do you respond to I-L-L?',
#  'What is your favorite game to play (either video game or IRL)?',
#  'What is your dream vacation location?']

# %% [markdown]
# ## Record the Variable for Your Question
#
# In the cell below, record your question's column name as a **string** variable named `analysis_column`.  You'll need that exact column name to reference data from that cell.

# %%
analysis_column =  "Do you prefer fall or spring?"
analysis_column
# Out:
# 'Do you prefer fall or spring?'

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('df' in vars()), "You do not have a DataFrame called `df`."
assert(len(df) >= 965), "You have not loaded the correct Hello dataset"
assert(analysis_column in df), "Make certain your analysis_column string is EXACTLY as it appears in the Hello Dataset."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Column Subset: View Only Your Question's Responses
#
# To begin your question's analysis, you first want to **focus only on your question**.  In lecture, we have primarily focused on creating subsets of rows. However, you can also create a subset of columns!
#
# To create a DataFrame with just a single column, you can use the syntax:
# ```
# df[ ["column name"] ]
# ```
# - Notice the **double set of square brackets**.  You need the outer set for `df`, and the inner set for the column name.
# - Because we've already loaded your question into `analysis_column`, you won't need the quotation marks this time
# - You can find this syntax under the "Subset Variables (Columns)" on your Pandas cheat sheet!
#
# With the `analysis_column` variable from above, use Python to display only the column you're analyzing.  This will make it easy to see what the two options were for your question:

# %%
df[ [analysis_column]]
# Out:
#     Do you prefer fall or spring?
# 0                            Fall
# 1                            Fall
# 2                            Fall
# 3                          Spring
# 4                            Fall
# ..                            ...
# 960                        Spring
# 961                          Fall
# 962                        Spring
# 963                          Fall
# 964                          Fall
#
# [965 rows x 1 columns]

# %% [markdown]
# ## DataFrame: Group One
#
# Create a DataFrame, `df1`, that contains everyone who picked the first option of your two answers.  *(Make sure to make this a subset of the original `df`, and not just your one column.)*

# %%
df1 = df[df[analysis_column] == "Fall"]
df1
# Out:
#             Name Section  \
# 0    Prof. Karle  L1, L2
# 1     Prof. Wade  L1, L2
# 2         Andrew     Y05
# 4         Ayden      Y14
# 6          Suvan     Y22
# ..           ...     ...
# 958       Hanle      Y12
# 959         Zoe      Y19
# 961        Peter     Y09
# 963       maddax      Y2
# 964   CA Sangjun     Y23
#
#     Does your NetID ending with odd number or even number?  \
# 0                        NetID ends with an odd number
# 1                                                  NaN
# 2                        NetID ends with an odd number
# 4                       NetID ends with an even number
# 6                       NetID ends with an even number
# ..                                                 ...
# 958                     NetID ends with an even number
# 959                     NetID ends with an even number
# 961                     NetID ends with an even number
# 963                      NetID ends with an odd number
# 964                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 0                                                Heads
# 1                                                Heads
# 2                                                Heads
# 4                                                Heads
# 6                                                Heads
# ..                                                 ...
# 958                                              Heads
# 959                                              Heads
# 961                                              Heads
# 963                                              Tails
# 964                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 0                                 Tacos                    0.0
# 1                                 Tacos                    1.0
# 2                                 Tacos                    1.0
# 4                                Donuts                    1.0
# 6                                Donuts                    1.0
# ..                                  ...                    ...
# 958                              Donuts                    0.0
# 959                               Tacos                    1.0
# 961                               Tacos                    1.0
# 963                               Tacos                    0.0
# 964                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 0                   Not a Freshman                         Night Person
# 1                   Not a Freshman                         Night Person
# 2              Freshman in College                         Night Person
# 4              Freshman in College                         Night Person
# 6              Freshman in College                         Night Person
# ..                             ...                                  ...
# 958                 Not a Freshman                         Night Person
# 959            Freshman in College                         Night Person
# 961                 Not a Freshman                       Morning Person
# 963            Freshman in College                         Night Person
# 964                 Not a Freshman                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 0                            Afternoon Person
# 1                            Afternoon Person
# 2                            Afternoon Person
# 4                              Morning Person
# 6                            Afternoon Person
# ..                                        ...
# 958                          Afternoon Person
# 959                          Afternoon Person
# 961                            Morning Person
# 963                          Afternoon Person
# 964                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 0                                           Illinois  ...
# 1                                                NaN  ...
# 2                                       Out-of-state  ...
# 4                                           Illinois  ...
# 6                                           Illinois  ...
# ..                                               ...  ...
# 958                                     Out-of-state  ...
# 959                                         Illinois  ...
# 961                                     Out-of-state  ...
# 963                                         Illinois  ...
# 964                                     Out-of-state  ...
#
#     From 1 to 10, how happy are you right now?  \
# 0                                         9.00
# 1                                         8.25
# 2                                         7.00
# 4                                         8.00
# 6                                         5.00
# ..                                         ...
# 958                                       6.00
# 959                                       7.00
# 961                                       5.00
# 963                                       1.00
# 964                                       8.00
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 0                                             moderate
# 1                                             Moderate
# 2                                             moderate
# 4                                               Strong
# 6                                               Strong
# ..                                                 ...
# 958                                             strong
# 959                                          Moderate
# 961                                             strong
# 963                                            extreme
# 964                                               Mild
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 0                                           Statistics
# 1                                             Grainger
# 2                                                  LAS
# 4                                                 Gies
# 6                      Statistics and Computer Science
# ..                                                 ...
# 958                                               Gies
# 959                              School of Information
# 961                                                 CS
# 963                          finance with data science
# 964                                         Statistics
#
#     What do you think is the hardest major at UIUC?  \
# 0                             Anything in GRAINGER!
# 1                                           Physics
# 2                                                CS
# 4                                   Any engineering
# 6                              Computer Engineering
# ..                                              ...
# 958                                             ECE
# 959                          Molecular engineering
# 961                                              CS
# 963                                         general
# 964                                     Engineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 0                           TAYLOR SWIFT!                       Taylor Swift
# 1                             Pop and EDM                       Taylor Swift
# 2                                     rap                               Dave
# 4                               Indie pop                      The Lumineers
# 6                                 Hip hop                        Don toliver
# ..                                    ...                                ...
# 958                                   All                        Post Malone
# 959   Everything (pop, R&B, rap, country)                      Taylor Swift
# 961                                  Jazz                                 Ye
# 963                                   rap                       lil uzi vert
# 964                                   RnB                      Wave to Earth
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 0                                Instagram                        I-N-I
# 1                                  YouTube                        I-N-I
# 2                                instagram                        I-N-I
# 4                                 Snapchat                          INI
# 6                                   Tiktok                         Ini
# ..                                     ...                          ...
# 958                                twitter                          ill
# 959                                Tiktok                        I-N-I!
# 961                                     QQ                         illi
# 963                               snapchat                          ini
# 964                              Instagram                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 0                                Any type of card game
# 1                                             Factorio
# 2                                               soccer
# 4                                           Basketball
# 6                                         20 questions
# ..                                                 ...
# 958                                  Rainbow six siege
# 959                                   Street Fighters
# 961                                     Clash of clans
# 963                                        quiet game
# 964                                     Clash of Clans
#
#     What is your dream vacation location?
# 0                            The Maldives
# 1                               Mountains
# 2                                  Hawaii
# 4                              Australia
# 6                             Switzerland
# ..                                    ...
# 958                       Japan, Hokkaido
# 959                               Greece
# 961                               Iceland
# 963                    middle of nowhere
# 964                                 Korea
#
# [629 rows x 178 columns]

# %% [markdown]
# ## DataFrame: Group Two
#
# Create a new DataFrame, `df2`, that contains everyone who picked the other answer:

# %%
df2 = df[df[analysis_column] == "Spring"]
df2
# Out:
#                        Name Section  \
# 3                  Annabel      Y05
# 5                      Sens     Y30
# 7                Joseph Kim     Y16
# 15                  Michael     Y03
# 16                   binchi     Y35
# ..                      ...     ...
# 952                    Erin     Y29
# 953                   Laura     Y28
# 957                 Arseniy     Y20
# 960  Mohammed Fatheen Ahmed     Y22
# 962                   Nyssa     Y23
#
#     Does your NetID ending with odd number or even number?  \
# 3                       NetID ends with an even number
# 5                       NetID ends with an even number
# 7                       NetID ends with an even number
# 15                      NetID ends with an even number
# 16                       NetID ends with an odd number
# ..                                                 ...
# 952                      NetID ends with an odd number
# 953                     NetID ends with an even number
# 957                                                NaN
# 960                      NetID ends with an odd number
# 962                      NetID ends with an odd number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 3                                                Heads
# 5                                                Heads
# 7                                                Heads
# 15                                               Heads
# 16                                               Tails
# ..                                                 ...
# 952                                              Heads
# 953                                              Heads
# 957                                              Heads
# 960                                              Heads
# 962                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 3                                 Tacos                    0.0
# 5                                 Tacos                    1.0
# 7                                Donuts                    1.0
# 15                                Tacos                    0.0
# 16                                Tacos                    0.0
# ..                                  ...                    ...
# 952                               Tacos                    1.0
# 953                              Donuts                    0.0
# 957                               Tacos                    1.0
# 960                              Donuts                    0.0
# 962                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 3                   Not a Freshman                         Night Person
# 5              Freshman in College                         Night Person
# 7                   Not a Freshman                         Night Person
# 15                  Not a Freshman                         Night Person
# 16             Freshman in College                       Morning Person
# ..                             ...                                  ...
# 952            Freshman in College                       Morning Person
# 953            Freshman in College                         Night Person
# 957                 Not a Freshman                         Night Person
# 960            Freshman in College                       Morning Person
# 962            Freshman in College                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 3                            Afternoon Person
# 5                              Morning Person
# 7                            Afternoon Person
# 15                           Afternoon Person
# 16                             Morning Person
# ..                                        ...
# 952                          Afternoon Person
# 953                          Afternoon Person
# 957                          Afternoon Person
# 960                            Morning Person
# 962                          Afternoon Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 3                                           Illinois  ...
# 5                                           Illinois  ...
# 7                                           Illinois  ...
# 15                                          Illinois  ...
# 16                                      Out-of-state  ...
# ..                                               ...  ...
# 952                                         Illinois  ...
# 953                                     Out-of-state  ...
# 957                                     Out-of-state  ...
# 960                                         Illinois  ...
# 962                                         Illinois  ...
#
#     From 1 to 10, how happy are you right now?  \
# 3                                          5.0
# 5                                          8.0
# 7                                          4.0
# 15                                        10.0
# 16                                         9.2
# ..                                         ...
# 952                                        6.0
# 953                                        8.0
# 957                                        7.0
# 960                                        3.0
# 962                                        8.0
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 3                                             Moderate
# 5                                             Moderate
# 7                                                 Mild
# 15                                             Extreme
# 16                                                mild
# ..                                                 ...
# 952                                             strong
# 953                                             Strong
# 957                                           moderate
# 960                                             strong
# 962                                               mild
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 3                                     ISchool and LAS
# 5                                     Grainger and LAS
# 7                                                  LAS
# 15                                                 LAS
# 16                                                math
# ..                                                 ...
# 952                                               UIUC
# 953                                               Gies
# 957                                                NaN
# 960                                                las
# 962                                                las
#
#     What do you think is the hardest major at UIUC?  \
# 3                                 Computer science
# 5                                               ECE
# 7                                  Computer Science
# 15                           Electrical Engineering
# 16                                             math
# ..                                              ...
# 952                                              CS
# 953                                    Engineering
# 957                                             NaN
# 960                                              CS
# 962                                             ece
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 3                              Rap or r&b                            Eminem
# 5                                Shoegaze                        Fiona Apple
# 7                              soundtrack             Ski Mask the Slump God
# 15                             Indie rock                           Pavement
# 16                                    R&B                                jay
# ..                                    ...                                ...
# 952          R&B, Indie music, pop, K-pop                       Shawn Mendes
# 953                                   Pop                         Eason Chen
# 957                                   NaN                                NaN
# 960                                   rap                              Drake
# 962                                   pop                       taylor swift
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 3                                Snapchat                           INI
# 5                                  Twitter                        I-N-I
# 7                                Instagram                    I-N-O-I-S
# 15                               Instagram                        I-N-I
# 16                                     ins                          ini
# ..                                     ...                          ...
# 952                              instagram                        I-N-I
# 953                              Instagram                        I-N-I
# 957                                    NaN                        I-N-I
# 960                                   Snap                         ini
# 962                                twitter                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 3                             Volleyball or fortnight
# 5                                            Fall Guys
# 7    Super Smash Bros. Ultimate (Dear Karle and Wad...
# 15                                            Baseball
# 16                                                FIFA
# ..                                                 ...
# 952                                                IRL
# 953                                               2048
# 957                                                NaN
# 960                                       apex legends
# 962                                         code names
#
#     What is your dream vacation location?
# 3                                 Greece
# 5                                      PR
# 7                                 Nowhere
# 15                                 France
# 16                                     LA
# ..                                    ...
# 952                              New York
# 953                                europe
# 957                        Moscow, Russia
# 960                                europe
# 962                                greece
#
# [326 rows x 178 columns]

# %% [markdown]
# ## Analysis
#
# Discuss the following questions with your group and then write down your response!

# %% [markdown]
# **Q1: What percentage of people chose each of your two binary options?**

# %% [markdown]
# 65% of students chose fall, and 33.7% of the students chose spring

# %% [markdown]
# **Q2: Did this surprise you? Why or why not? Write at least one complete sentence.**

# %% [markdown]
# Yes, we found this suprising because we thought that since both seasons are relatively similar, the amount of people that liked one would be similar to the amount of students that liked the other.

# %% [markdown]
# **Q3: Do you think your question was the closest to a perfect 50/50 split among the whole class?**

# %% [markdown]
# No

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Part 2: Creating Treatment and Control Groups
#
# For the rest of this lab, we will consider the "Hello Dataset" to be a pre-survey of randomly selected participants for an upcoming experiment.  In lecture, you learned that a good experiment will split the participants into two groups: the "treatment" group and the "control" group.
#
# Recall that it is necessary to have both groups:
#
# - The "control" group is a comparison group that will receive a placebo and will act as a control to ensure that the treatment has an effect.
# - The "treatment" group will receive a treatment and we will look for differences between the results of this treatment group and the control group.

# %% [markdown]
# ## Part 2.1: Select a Treatment Group
#
# Select half (50%) of the participants from our original `df` to be in the treatment group and place them into a DataFrame called `treatment`.
# - Remember, you can ask your CAs, TAs, or use your **pandas cheat sheet** to help you out!

# %%
treatment = df.sample(frac=.5)
treatment
# Out:
#             Name   Section  \
# 3       Annabel        Y05
# 60         Rylan       Y13
# 339      Michael       Y34
# 333       Lening       Y02
# 766  TA Chandler  Y06, Y33
# ..           ...       ...
# 871       Braden       Y22
# 553          Ray       Y29
# 949     Vihaansh       Y08
# 441        Aaron       Y26
# 944       Mahdia       Y06
#
#     Does your NetID ending with odd number or even number?  \
# 3                       NetID ends with an even number
# 60                       NetID ends with an odd number
# 339                      NetID ends with an odd number
# 333                     NetID ends with an even number
# 766                     NetID ends with an even number
# ..                                                 ...
# 871                     NetID ends with an even number
# 553                      NetID ends with an odd number
# 949                      NetID ends with an odd number
# 441                     NetID ends with an even number
# 944                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 3                                                Heads
# 60                                               Heads
# 339                                              Heads
# 333                                              Heads
# 766                                              Tails
# ..                                                 ...
# 871                                              Heads
# 553                                              Heads
# 949                                              Heads
# 441                                              Tails
# 944                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 3                                 Tacos                    0.0
# 60                                Tacos                    1.0
# 339                               Tacos                    1.0
# 333                               Tacos                    0.0
# 766                               Tacos                    0.0
# ..                                  ...                    ...
# 871                              Donuts                    0.0
# 553                               Tacos                    1.0
# 949                               Tacos                    1.0
# 441                               Tacos                    1.0
# 944                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 3                   Not a Freshman                         Night Person
# 60                  Not a Freshman                         Night Person
# 339            Freshman in College                         Night Person
# 333                 Not a Freshman                         Night Person
# 766                 Not a Freshman                         Night Person
# ..                             ...                                  ...
# 871            Freshman in College                         Night Person
# 553                 Not a Freshman                         Night Person
# 949                 Not a Freshman                         Night Person
# 441            Freshman in College                         Night Person
# 944                 Not a Freshman                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 3                            Afternoon Person
# 60                           Afternoon Person
# 339                          Afternoon Person
# 333                          Afternoon Person
# 766                          Afternoon Person
# ..                                        ...
# 871                          Afternoon Person
# 553                            Morning Person
# 949                          Afternoon Person
# 441                          Afternoon Person
# 944                          Afternoon Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 3                                           Illinois  ...
# 60                                          Illinois  ...
# 339                                     Out-of-state  ...
# 333                                     Out-of-state  ...
# 766                                     Out-of-state  ...
# ..                                               ...  ...
# 871                                         Illinois  ...
# 553                                         Illinois  ...
# 949                                     Out-of-state  ...
# 441                                     Out-of-state  ...
# 944                                         Illinois  ...
#
#     From 1 to 10, how happy are you right now?  \
# 3                                          5.0
# 60                                         7.0
# 339                                        9.0
# 333                                        6.0
# 766                                        4.0
# ..                                         ...
# 871                                        8.0
# 553                                        8.0
# 949                                        7.0
# 441                                        7.0
# 944                                        7.0
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 3                                             Moderate
# 60                                              strong
# 339                                               mild
# 333                                            extreme
# 766                                             Strong
# ..                                                 ...
# 871                                           Moderate
# 553                                               mild
# 949                                            Extreme
# 441                                             Strong
# 944                                           moderate
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 3                                     ISchool and LAS
# 60                                             iSchool
# 339                                                LAS
# 333                                                LAS
# 766                                                LAS
# ..                                                 ...
# 871                                               Gies
# 553                                                LAS
# 949                               Computer Engineering
# 441                                                LAS
# 944                               Information sciences
#
#     What do you think is the hardest major at UIUC?  \
# 3                                 Computer science
# 60                           Biomedical Engineering
# 339                                         Physics
# 333                                              CS
# 766                                Computer Science
# ..                                              ...
# 871                                              CS
# 553                                             ece
# 949                          Electrical Engineering
# 441                                Computer Science
# 944                                computer science
#
#     What genre of music do you listen to?  Who is your favorite music artist?  \
# 3                              Rap or r&b                             Eminem
# 60                          Electro Swing                           TheFatRat
# 339                             Pop music                           Lang lang
# 333                                   R&B                             Galdive
# 766                  Classical/Electronic  Tchaikovsky/Beatles/Wagner/Justice
# ..                                    ...                                 ...
# 871                                   Rap                         Post Malone
# 553                                  jpop                                 Eve
# 949                                  Rock                              Eminem
# 441                            Everything                       Jeremy Zucker
# 944                                 indie                        taylor swift
#
#     What's your favorite social media app?    How do you respond to I-L-L?  \
# 3                                Snapchat                              INI
# 60                                 Discord                           I-N-I
# 339                                 Tiktok                      Lay on bed
# 333                              Instagram                             INI
# 766                                 Reddit  Do you need medical attention?
# ..                                     ...                             ...
# 871                              Instagram                             INI
# 553                                 tiktok                             INI
# 949                              Instagram                           I-N-I
# 441                              Instagram                           I-N-I
# 944                              instagram                             INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 3                             Volleyball or fortnight
# 60                                           Minecraft
# 339                                       Apex legends
# 333                                       It takes two
# 766                                              Chess
# ..                                                 ...
# 871                                               Golf
# 553                                     genshin impact
# 949                                             Soccer
# 441                                         Basketball
# 944                                          beer pong
#
#     What is your dream vacation location?
# 3                                 Greece
# 60                                Boracay
# 339                     Xinjiang in China
# 333                             Australia
# 766                                  Mars
# ..                                    ...
# 871                                 Aruba
# 553                                 japan
# 949                                Norway
# 441                                 Japan
# 944                                  cabo
#
# [482 rows x 178 columns]

# %% [markdown]
# ## Part 2.2: Select a Control Group
#
# Using the **exact same technique and syntax** as you did above, also select half (50%) of the participants to be in the control group.  Place them into a DataFrame called `control`. For now, it's okay if there are people who are in both groups.

# %%
control = df.sample(frac=.5)
control
# Out:
#             Name Section  \
# 105          Ivy     Y36
# 616         Ziqi     Y27
# 182         Asha     Y21
# 800        Chris     Y35
# 495         Owen     Y15
# ..           ...     ...
# 477       Nathan     Y35
# 249          Tim     Y28
# 636        Aditi     Y19
# 763  Rohan Thope     Y29
# 369          Ian     Y13
#
#     Does your NetID ending with odd number or even number?  \
# 105                     NetID ends with an even number
# 616                      NetID ends with an odd number
# 182                     NetID ends with an even number
# 800                      NetID ends with an odd number
# 495                     NetID ends with an even number
# ..                                                 ...
# 477                     NetID ends with an even number
# 249                     NetID ends with an even number
# 636                     NetID ends with an even number
# 763                     NetID ends with an even number
# 369                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 105                                              Heads
# 616                                              Heads
# 182                                              Tails
# 800                                              Tails
# 495                                              Heads
# ..                                                 ...
# 477                                              Heads
# 249                                              Heads
# 636                                              Tails
# 763                                              Heads
# 369                                              Tails
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 105                              Donuts                    1.0
# 616                              Donuts                    1.0
# 182                              Donuts                    1.0
# 800                               Tacos                    1.0
# 495                               Tacos                    0.0
# ..                                  ...                    ...
# 477                               Tacos                    0.0
# 249                               Tacos                    0.0
# 636                               Tacos                    1.0
# 763                               Tacos                    1.0
# 369                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 105            Freshman in College                       Morning Person
# 616            Freshman in College                         Night Person
# 182            Freshman in College                         Night Person
# 800                 Not a Freshman                       Morning Person
# 495                 Not a Freshman                       Morning Person
# ..                             ...                                  ...
# 477            Freshman in College                         Night Person
# 249            Freshman in College                         Night Person
# 636                 Not a Freshman                         Night Person
# 763            Freshman in College                         Night Person
# 369                 Not a Freshman                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 105                            Morning Person
# 616                          Afternoon Person
# 182                          Afternoon Person
# 800                            Morning Person
# 495                            Morning Person
# ..                                        ...
# 477                          Afternoon Person
# 249                          Afternoon Person
# 636                          Afternoon Person
# 763                          Afternoon Person
# 369                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 105                                     Out-of-state  ...
# 616                                     Out-of-state  ...
# 182                                         Illinois  ...
# 800                                         Illinois  ...
# 495                                         Illinois  ...
# ..                                               ...  ...
# 477                                     Out-of-state  ...
# 249                                         Illinois  ...
# 636                                              NaN  ...
# 763                                         Illinois  ...
# 369                                         Illinois  ...
#
#     From 1 to 10, how happy are you right now?  \
# 105                                        7.0
# 616                                        5.0
# 182                                        8.0
# 800                                        5.0
# 495                                        7.0
# ..                                         ...
# 477                                        4.0
# 249                                        7.0
# 636                                        NaN
# 763                                        7.0
# 369                                        5.0
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 105                                           moderate
# 616                                             strong
# 182                                            Extreme
# 800                                             Strong
# 495                                             Strong
# ..                                                 ...
# 477                                               Mild
# 249                                           moderate
# 636                                                NaN
# 763                                           moderate
# 369                                             strong
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 105                               finance+data science
# 616                                               Math
# 182                                               Gies
# 800                                               Gies
# 495                                               Gies
# ..                                                 ...
# 477                                               Gies
# 249                                                LAS
# 636                                                NaN
# 763                                Information Systems
# 369                                                LAS
#
#     What do you think is the hardest major at UIUC?  \
# 105                                      undeclared
# 616                                              cs
# 182                                              CS
# 800                                Computer Science
# 495                            Computer Engineering
# ..                                              ...
# 477                                              CS
# 249                                             NaN
# 636                                             NaN
# 763                         mechanical engingeering
# 369                            Computer Engineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 105                                   rap                             J.Cole
# 616                              Hip-hop                        Metro Boomin
# 182             All genres except country                        Frank Ocean
# 800                                  Rock                         Steve Lacy
# 495                            Indie/Folk                         Kanye West
# ..                                    ...                                ...
# 477                          Jazz and R&B                      Daniel Caesar
# 249                                   NaN                                NaN
# 636                                   NaN                                NaN
# 763                                   Pop                         Bruno Mars
# 369                    All except country                        One Ok Rock
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 105                                 WeChat                          INI
# 616                                    ins                            u
# 182                              Messages?                          INI
# 800                              Instagram                          INI
# 495                               Snapchat                        I-N-I
# ..                                     ...                          ...
# 477                                YouTube                          INI
# 249                                YouTube                          INI
# 636                                    NaN                          NaN
# 763                              Instagram                          INI
# 369                                Discord                   eye en eye
#
#     What is your favorite game to play (either video game or IRL)?  \
# 105                                            genshen
# 616                                                LOL
# 182                            Pokemon Legends: Arceus
# 800                                           Baseball
# 495                                         Basketball
# ..                                                 ...
# 477                                           Valorant
# 249                                         Basketball
# 636                                                NaN
# 763                                             tennis
# 369                          Super Smash Bros Ultimate
#
#     What is your dream vacation location?
# 105                               Iceland
# 616                                    LA
# 182                           Philippines
# 800                                Dublin
# 495                                Greece
# ..                                    ...
# 477                              Maldives
# 249                               Iceland
# 636                                   NaN
# 763                             Santorini
# 369                                 Japan
#
# [482 rows x 178 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( len(treatment) == len(control) ), "The `treatment` and `control` groups must be the same size."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`"
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`"


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Analysis: Overlapping Selection?
#
# The following code will detect rows that are **both in your treatment and control** groups.
#
# Run the following cell to see everyone who is in both groups:

# %%
df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]
# Out:
#                   Name Section  \
# 2               Andrew     Y05
# 3             Annabel      Y05
# 13              rachel     Y18
# 15             Michael     Y03
# 17              Chuyan     Y24
# ..                 ...     ...
# 945             Jenny      Y01
# 951  Anuraag Aravindan     Y30
# 952               Erin     Y29
# 957            Arseniy     Y20
# 961              Peter     Y09
#
#     Does your NetID ending with odd number or even number?  \
# 2                        NetID ends with an odd number
# 3                       NetID ends with an even number
# 13                      NetID ends with an even number
# 15                      NetID ends with an even number
# 17                      NetID ends with an even number
# ..                                                 ...
# 945                     NetID ends with an even number
# 951                     NetID ends with an even number
# 952                      NetID ends with an odd number
# 957                                                NaN
# 961                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 2                                                Heads
# 3                                                Heads
# 13                                               Tails
# 15                                               Heads
# 17                                               Heads
# ..                                                 ...
# 945                                              Heads
# 951                                              Heads
# 952                                              Heads
# 957                                              Heads
# 961                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 2                                 Tacos                    1.0
# 3                                 Tacos                    0.0
# 13                                Tacos                    1.0
# 15                                Tacos                    0.0
# 17                               Donuts                    0.0
# ..                                  ...                    ...
# 945                               Tacos                    1.0
# 951                              Donuts                    0.0
# 952                               Tacos                    1.0
# 957                               Tacos                    1.0
# 961                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 2              Freshman in College                         Night Person
# 3                   Not a Freshman                         Night Person
# 13             Freshman in College                         Night Person
# 15                  Not a Freshman                         Night Person
# 17             Freshman in College                         Night Person
# ..                             ...                                  ...
# 945            Freshman in College                         Night Person
# 951            Freshman in College                       Morning Person
# 952            Freshman in College                       Morning Person
# 957                 Not a Freshman                         Night Person
# 961                 Not a Freshman                       Morning Person
#
#     Are you a morning or an afternoon person?  \
# 2                            Afternoon Person
# 3                            Afternoon Person
# 13                             Morning Person
# 15                           Afternoon Person
# 17                           Afternoon Person
# ..                                        ...
# 945                          Afternoon Person
# 951                            Morning Person
# 952                          Afternoon Person
# 957                          Afternoon Person
# 961                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 2                                       Out-of-state  ...
# 3                                           Illinois  ...
# 13                                          Illinois  ...
# 15                                          Illinois  ...
# 17                                      Out-of-state  ...
# ..                                               ...  ...
# 945                                     Out-of-state  ...
# 951                                     Out-of-state  ...
# 952                                         Illinois  ...
# 957                                     Out-of-state  ...
# 961                                     Out-of-state  ...
#
#     From 1 to 10, how happy are you right now?  \
# 2                                          7.0
# 3                                          5.0
# 13                                         7.0
# 15                                        10.0
# 17                                         7.0
# ..                                         ...
# 945                                        NaN
# 951                                        4.0
# 952                                        6.0
# 957                                        7.0
# 961                                        5.0
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 2                                             moderate
# 3                                             Moderate
# 13                                              strong
# 15                                             Extreme
# 17                                             extreme
# ..                                                 ...
# 945                                                NaN
# 951                                             strong
# 952                                             strong
# 957                                           moderate
# 961                                             strong
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 2                                                  LAS
# 3                                     ISchool and LAS
# 13                                           grainger
# 15                                                 LAS
# 17                                            business
# ..                                                 ...
# 945                                                NaN
# 951                                                LAS
# 952                                               UIUC
# 957                                                NaN
# 961                                                 CS
#
#     What do you think is the hardest major at UIUC?  \
# 2                                                CS
# 3                                 Computer science
# 13                         biochemical engineering
# 15                           Electrical Engineering
# 17                                               CS
# ..                                              ...
# 945                                             NaN
# 951                                         Physics
# 952                                              CS
# 957                                             NaN
# 961                                              CS
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 2                                     rap                               Dave
# 3                              Rap or r&b                            Eminem
# 13                                    pop                           newjeans
# 15                             Indie rock                           Pavement
# 17                                    R&B                           Jay Chou
# ..                                    ...                                ...
# 945                                   NaN                                NaN
# 951                            Everything                              drake
# 952          R&B, Indie music, pop, K-pop                       Shawn Mendes
# 957                                   NaN                                NaN
# 961                                  Jazz                                 Ye
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 2                                instagram                        I-N-I
# 3                                Snapchat                           INI
# 13                              instagram                         I-N-I
# 15                               Instagram                        I-N-I
# 17                                  Wechat                    Illinois?
# ..                                     ...                          ...
# 945                                    NaN                          NaN
# 951                              Instagram                          INI
# 952                              instagram                        I-N-I
# 957                                    NaN                        I-N-I
# 961                                     QQ                         illi
#
#     What is your favorite game to play (either video game or IRL)?  \
# 2                                               soccer
# 3                             Volleyball or fortnight
# 13                                              euchre
# 15                                            Baseball
# 17                                                none
# ..                                                 ...
# 945                                                NaN
# 951                                             tennis
# 952                                                IRL
# 957                                                NaN
# 961                                     Clash of clans
#
#     What is your dream vacation location?
# 2                                  Hawaii
# 3                                 Greece
# 13                                 hawaii
# 15                                 France
# 17         travel with friends and family
# ..                                    ...
# 945                                   NaN
# 951                             australia
# 952                              New York
# 957                        Moscow, Russia
# 961                               Iceland
#
# [242 rows x 178 columns]

# %% [markdown]
# **Q: Why would your code result in some people being included in both groups? Write at least one complete sentence explaining why you think this might occur.**

# %% [markdown]
# Because we split the original df twice, and we did not change anything to ignore the repeated people

# %% [markdown]
# ## Part 2.3:
#
# Read the following guide on **using `.index.isin` to select all rows from a DataFrame not in another DataFrame**: https://discovery.cs.illinois.edu/guides/DataFrame-Row-Selection/dataframe-isin-selection/
#
# Finally, create a new `control` group that contains all of the participants from `df` that are not in `treatment`:

# %%
control = df[ ~df.index.isin(treatment.index) ]
control
# Out:
#             Name Section  \
# 0    Prof. Karle  L1, L2
# 1     Prof. Wade  L1, L2
# 4         Ayden      Y14
# 5           Sens     Y30
# 6          Suvan     Y22
# ..           ...     ...
# 953        Laura     Y28
# 958       Hanle      Y12
# 959         Zoe      Y19
# 962        Nyssa     Y23
# 963       maddax      Y2
#
#     Does your NetID ending with odd number or even number?  \
# 0                        NetID ends with an odd number
# 1                                                  NaN
# 4                       NetID ends with an even number
# 5                       NetID ends with an even number
# 6                       NetID ends with an even number
# ..                                                 ...
# 953                     NetID ends with an even number
# 958                     NetID ends with an even number
# 959                     NetID ends with an even number
# 962                      NetID ends with an odd number
# 963                      NetID ends with an odd number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 0                                                Heads
# 1                                                Heads
# 4                                                Heads
# 5                                                Heads
# 6                                                Heads
# ..                                                 ...
# 953                                              Heads
# 958                                              Heads
# 959                                              Heads
# 962                                              Heads
# 963                                              Tails
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 0                                 Tacos                    0.0
# 1                                 Tacos                    1.0
# 4                                Donuts                    1.0
# 5                                 Tacos                    1.0
# 6                                Donuts                    1.0
# ..                                  ...                    ...
# 953                              Donuts                    0.0
# 958                              Donuts                    0.0
# 959                               Tacos                    1.0
# 962                               Tacos                    1.0
# 963                               Tacos                    0.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 0                   Not a Freshman                         Night Person
# 1                   Not a Freshman                         Night Person
# 4              Freshman in College                         Night Person
# 5              Freshman in College                         Night Person
# 6              Freshman in College                         Night Person
# ..                             ...                                  ...
# 953            Freshman in College                         Night Person
# 958                 Not a Freshman                         Night Person
# 959            Freshman in College                         Night Person
# 962            Freshman in College                         Night Person
# 963            Freshman in College                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 0                            Afternoon Person
# 1                            Afternoon Person
# 4                              Morning Person
# 5                              Morning Person
# 6                            Afternoon Person
# ..                                        ...
# 953                          Afternoon Person
# 958                          Afternoon Person
# 959                          Afternoon Person
# 962                          Afternoon Person
# 963                          Afternoon Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 0                                           Illinois  ...
# 1                                                NaN  ...
# 4                                           Illinois  ...
# 5                                           Illinois  ...
# 6                                           Illinois  ...
# ..                                               ...  ...
# 953                                     Out-of-state  ...
# 958                                     Out-of-state  ...
# 959                                         Illinois  ...
# 962                                         Illinois  ...
# 963                                         Illinois  ...
#
#     From 1 to 10, how happy are you right now?  \
# 0                                         9.00
# 1                                         8.25
# 4                                         8.00
# 5                                         8.00
# 6                                         5.00
# ..                                         ...
# 953                                       8.00
# 958                                       6.00
# 959                                       7.00
# 962                                       8.00
# 963                                       1.00
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 0                                             moderate
# 1                                             Moderate
# 4                                               Strong
# 5                                             Moderate
# 6                                               Strong
# ..                                                 ...
# 953                                             Strong
# 958                                             strong
# 959                                          Moderate
# 962                                               mild
# 963                                            extreme
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 0                                           Statistics
# 1                                             Grainger
# 4                                                 Gies
# 5                                     Grainger and LAS
# 6                      Statistics and Computer Science
# ..                                                 ...
# 953                                               Gies
# 958                                               Gies
# 959                              School of Information
# 962                                                las
# 963                          finance with data science
#
#     What do you think is the hardest major at UIUC?  \
# 0                             Anything in GRAINGER!
# 1                                           Physics
# 4                                   Any engineering
# 5                                               ECE
# 6                              Computer Engineering
# ..                                              ...
# 953                                    Engineering
# 958                                             ECE
# 959                          Molecular engineering
# 962                                             ece
# 963                                         general
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 0                           TAYLOR SWIFT!                       Taylor Swift
# 1                             Pop and EDM                       Taylor Swift
# 4                               Indie pop                      The Lumineers
# 5                                Shoegaze                        Fiona Apple
# 6                                 Hip hop                        Don toliver
# ..                                    ...                                ...
# 953                                   Pop                         Eason Chen
# 958                                   All                        Post Malone
# 959   Everything (pop, R&B, rap, country)                      Taylor Swift
# 962                                   pop                       taylor swift
# 963                                   rap                       lil uzi vert
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 0                                Instagram                        I-N-I
# 1                                  YouTube                        I-N-I
# 4                                 Snapchat                          INI
# 5                                  Twitter                        I-N-I
# 6                                   Tiktok                         Ini
# ..                                     ...                          ...
# 953                              Instagram                        I-N-I
# 958                                twitter                          ill
# 959                                Tiktok                        I-N-I!
# 962                                twitter                          INI
# 963                               snapchat                          ini
#
#     What is your favorite game to play (either video game or IRL)?  \
# 0                                Any type of card game
# 1                                             Factorio
# 4                                           Basketball
# 5                                            Fall Guys
# 6                                         20 questions
# ..                                                 ...
# 953                                               2048
# 958                                  Rainbow six siege
# 959                                   Street Fighters
# 962                                         code names
# 963                                        quiet game
#
#     What is your dream vacation location?
# 0                            The Maldives
# 1                               Mountains
# 4                              Australia
# 5                                      PR
# 6                             Switzerland
# ..                                    ...
# 953                                europe
# 958                       Japan, Hokkaido
# 959                               Greece
# 962                                greece
# 963                    middle of nowhere
#
# [483 rows x 178 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`"
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`"
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 2.4: Finding Yourself!
#
# Use the following cells to write Python code to find yourself in either the treatment group or control group.
# - **Hint**: How do you select a subset of rows?  What conditional will identify you??
# - If you did not fill out the "Hello Survey" then you are not in this dataset. :(
# - If you are not in this survey, find either "Prof. Wade" or "Prof. Karle" instead.  *(Those are the names we used in the `Name` column.)*

# %%
control[control.Name=="Hamza"]
# Out:
#       Name Section Does your NetID ending with odd number or even number?  \
# 254  Hamza     Y26                      NetID ends with an odd number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 254                                              Tails
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 254                              Donuts                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 254            Freshman in College                       Morning Person
#
#     Are you a morning or an afternoon person?  \
# 254                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 254                                         Illinois  ...
#
#     From 1 to 10, how happy are you right now?  \
# 254                                       10.0
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 254                                               Mild
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 254                                               Gies
#
#     What do you think is the hardest major at UIUC?  \
# 254                           Chemical Engineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 254                                   Rap                       Travis Scott
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 254                               Snapchat                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 254                                              NBA2k
#
#     What is your dream vacation location?
# 254                            Australia
#
# [1 rows x 178 columns]

# %% [markdown]
# ## Analysis: Finding Yourself!
#
# **Q: Which group where you in -- treatment or control?**

# %% [markdown]
# Control

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: Using Blocking to Create Treatment and Control Groups that are Balanced
#
# In your pre-experiment research, you have reason to believe that how the participants answer **your group's question** might influence the response of this experiment!  Oh no! Even though this is a large sample of participants, we want to block to be absolutely sure that the treatment and control groups are balanced with regard to your group's question!
#
# To control for this, we will using **blocking**!  Remember from lecture that blocking refers to creating subgroups for each response, selecting equal-sized treatment and control groups from each block, and then combining all the treatment groups together and all the control groups together to get the final groups. This ensures that your groups are balanced with regard to the variable you blocked on!
#
# You have already done some of this work:
# - Earlier in this notebook, you created `df1` that includes everyone who answered your group's question one way.
# - Earlier in this notebook, you created `df2` that includes everyone who answered your group's question the other way.

# %% [markdown]
# ## Part 3.1:
#
# Create a `df1_treatment` group that contains a random selection of 50% of the rows from `df1`.

# %%
df1_treatment = df1.sample(frac=.5)
df1_treatment
# Out:
#                        Name Section  \
# 902                    Tony     Y35
# 181        Pranav Penaganti     Y13
# 144                 Xiaolin     Y02
# 897                   Rahil     Y08
# 595  Karle from Section Y23     Y23
# ..                      ...     ...
# 408                   Soham     Y12
# 753                   Alia      Y03
# 697                Rakshita     Y24
# 877                Pranjall     Y34
# 248                 Amarisa     Y14
#
#     Does your NetID ending with odd number or even number?  \
# 902                      NetID ends with an odd number
# 181                      NetID ends with an odd number
# 144                      NetID ends with an odd number
# 897                      NetID ends with an odd number
# 595                     NetID ends with an even number
# ..                                                 ...
# 408                      NetID ends with an odd number
# 753                      NetID ends with an odd number
# 697                     NetID ends with an even number
# 877                     NetID ends with an even number
# 248                      NetID ends with an odd number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 902                                              Heads
# 181                                              Tails
# 144                                              Heads
# 897                                              Tails
# 595                                              Heads
# ..                                                 ...
# 408                                              Tails
# 753                                              Heads
# 697                                              Tails
# 877                                              Tails
# 248                                              Tails
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 902                              Donuts                    1.0
# 181                              Donuts                    1.0
# 144                              Donuts                    1.0
# 897                              Donuts                    0.0
# 595                              Donuts                    1.0
# ..                                  ...                    ...
# 408                              Donuts                    0.0
# 753                              Donuts                    0.0
# 697                               Tacos                    1.0
# 877                               Tacos                    1.0
# 248                              Donuts                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 902                 Not a Freshman                         Night Person
# 181                 Not a Freshman                         Night Person
# 144                 Not a Freshman                       Morning Person
# 897            Freshman in College                         Night Person
# 595            Freshman in College                         Night Person
# ..                             ...                                  ...
# 408            Freshman in College                       Morning Person
# 753                 Not a Freshman                       Morning Person
# 697            Freshman in College                         Night Person
# 877            Freshman in College                         Night Person
# 248            Freshman in College                       Morning Person
#
#     Are you a morning or an afternoon person?  \
# 902                          Afternoon Person
# 181                          Afternoon Person
# 144                            Morning Person
# 897                            Morning Person
# 595                          Afternoon Person
# ..                                        ...
# 408                          Afternoon Person
# 753                            Morning Person
# 697                          Afternoon Person
# 877                          Afternoon Person
# 248                          Afternoon Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 902                                     Out-of-state  ...
# 181                                     Out-of-state  ...
# 144                                         Illinois  ...
# 897                                     Out-of-state  ...
# 595                                     Out-of-state  ...
# ..                                               ...  ...
# 408                                         Illinois  ...
# 753                                         Illinois  ...
# 697                                         Illinois  ...
# 877                                     Out-of-state  ...
# 248                                     Out-of-state  ...
#
#     From 1 to 10, how happy are you right now?  \
# 902                                        3.0
# 181                                        3.0
# 144                                        8.0
# 897                                        9.0
# 595                                        7.0
# ..                                         ...
# 408                                        7.0
# 753                                       10.0
# 697                                        7.0
# 877                                        9.0
# 248                                        6.5
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 902                                               mild
# 181                                           Moderate
# 144                                           moderate
# 897                                            extreme
# 595                                            extreme
# ..                                                 ...
# 408                                          moderate
# 753                                             Strong
# 697                                             strong
# 877                                             strong
# 248                                             Strong
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 902                           Gies college of Business
# 181                               Grainger Engineering
# 144                                         Psychology
# 897                                            iSchool
# 595                                               Gies
# ..                                                 ...
# 408                                      GIES- finance
# 753                                            iSchool
# 697                           Gies College of Business
# 877                                               Gies
# 248                                                LAS
#
#     What do you think is the hardest major at UIUC?  \
# 902                                              CS
# 181                            Computer Engineering
# 144                                     Engineering
# 897                                              CS
# 595                                              CS
# ..                                              ...
# 408                                       Chemistry
# 753                                           CompE
# 697                                Computer Science
# 877                          Electrical Engineering
# 248                                         Physics
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 902                        popular music                            Jay Chou
# 181                       Rap/Pop/Country                               Yeat
# 144                                   Pop                          BLACKPINK
# 897                                   rap                           Kid Cudi
# 595         All honestly except for K-pop                                NaN
# ..                                    ...                                ...
# 408                                   RAP                          21 Savage
# 753                                   Pop                       Lana Del Rey
# 697                                   Rap                              Drake
# 877                       rap and hip-hop                              drake
# 248                                Hippie                       Taylor Swift
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 902                              Instagram                   No respond
# 181                              Instagram                          INI
# 144                                Spotify                     Illinois
# 897                                      X                        i n i
# 595                                 BeReal                        I-N-I
# ..                                     ...                          ...
# 408                               Snapchat                          INI
# 753                              Instagram                        I-N-I
# 697                               Snapchat                        I-N-I
# 877                              Instagram                        I-N-I
# 248                              Instagram                        L-O-L
#
#     What is your favorite game to play (either video game or IRL)?  \
# 902                                          Minecraft
# 181                                                GTA
# 144                              Honor of Kings: World
# 897                                               fifa
# 595                                               Ludo
# ..                                                 ...
# 408                                         Basketball
# 753                                              Cards
# 697                                              run 2
# 877                                           football
# 248                                          Minecraft
#
#     What is your dream vacation location?
# 902                                Bahama
# 181                                 Ibiza
# 144                                 China
# 897                                 India
# 595                                 Italy
# ..                                    ...
# 408                                 India
# 753                               Montana
# 697                                Greece
# 877                                  cabo
# 248                     A scottish castle
#
# [314 rows x 178 columns]

# %% [markdown]
# ## Part 3.2:
#
# Create a `df1_control` group that contains the other half of the rows from `df1`. *(You can refer back to Part 2 to refresh on how to do this, make sure you use `df1` and `df1_control` as your DataFrames.)*

# %%
df1_control = df1[ ~df1.index.isin(df1_treatment.index) ]
df1_control
# Out:
#                 Name Section  \
# 1         Prof. Wade  L1, L2
# 4             Ayden      Y14
# 8              Sarah     Y36
# 9    Pradnyan Khodke     Y24
# 10           Aaliyah     Y13
# ..               ...     ...
# 950           Albert     Y02
# 955         lijiajin     Y01
# 956          Fabian      Y11
# 959             Zoe      Y19
# 961            Peter     Y09
#
#     Does your NetID ending with odd number or even number?  \
# 1                                                  NaN
# 4                       NetID ends with an even number
# 8                        NetID ends with an odd number
# 9                        NetID ends with an odd number
# 10                      NetID ends with an even number
# ..                                                 ...
# 950                     NetID ends with an even number
# 955                      NetID ends with an odd number
# 956                      NetID ends with an odd number
# 959                     NetID ends with an even number
# 961                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 1                                                Heads
# 4                                                Heads
# 8                                                Heads
# 9                                                Heads
# 10                                               Heads
# ..                                                 ...
# 950                                              Tails
# 955                                              Heads
# 956                                              Tails
# 959                                              Heads
# 961                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 1                                 Tacos                    1.0
# 4                                Donuts                    1.0
# 8                                Donuts                    0.0
# 9                                 Tacos                    1.0
# 10                               Donuts                    1.0
# ..                                  ...                    ...
# 950                               Tacos                    1.0
# 955                              Donuts                    0.0
# 956                               Tacos                    0.0
# 959                               Tacos                    1.0
# 961                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 1                   Not a Freshman                         Night Person
# 4              Freshman in College                         Night Person
# 8              Freshman in College                       Morning Person
# 9                   Not a Freshman                       Morning Person
# 10             Freshman in College                         Night Person
# ..                             ...                                  ...
# 950            Freshman in College                         Night Person
# 955                 Not a Freshman                         Night Person
# 956                 Not a Freshman                         Night Person
# 959            Freshman in College                         Night Person
# 961                 Not a Freshman                       Morning Person
#
#     Are you a morning or an afternoon person?  \
# 1                            Afternoon Person
# 4                              Morning Person
# 8                              Morning Person
# 9                              Morning Person
# 10                           Afternoon Person
# ..                                        ...
# 950                          Afternoon Person
# 955                            Morning Person
# 956                          Afternoon Person
# 959                          Afternoon Person
# 961                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 1                                                NaN  ...
# 4                                           Illinois  ...
# 8                                           Illinois  ...
# 9                                           Illinois  ...
# 10                                          Illinois  ...
# ..                                               ...  ...
# 950                                         Illinois  ...
# 955                                     Out-of-state  ...
# 956                                         Illinois  ...
# 959                                         Illinois  ...
# 961                                     Out-of-state  ...
#
#     From 1 to 10, how happy are you right now?  \
# 1                                         8.25
# 4                                         8.00
# 8                                         7.00
# 9                                         5.00
# 10                                        8.00
# ..                                         ...
# 950                                       7.00
# 955                                       5.00
# 956                                       4.00
# 959                                       7.00
# 961                                       5.00
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 1                                             Moderate
# 4                                               Strong
# 8                                               Strong
# 9                                               Strong
# 10                                             Extreme
# ..                                                 ...
# 950                                             strong
# 955                                             strong
# 956                                           Extreme
# 959                                          Moderate
# 961                                             strong
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 1                                             Grainger
# 4                                                 Gies
# 8                                              iSchool
# 9                                                  LAS
# 10                                             iSchool
# ..                                                 ...
# 950                                                DgS
# 955                                                 cs
# 956                                                 IS
# 959                              School of Information
# 961                                                 CS
#
#     What do you think is the hardest major at UIUC?  \
# 1                                           Physics
# 4                                   Any engineering
# 8                                  Computer Science
# 9                                               ECE
# 10                                 Computer Science
# ..                                              ...
# 950                                       Chemistry
# 955                                              cs
# 956                               Computer science
# 959                          Molecular engineering
# 961                                              CS
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 1                             Pop and EDM                       Taylor Swift
# 4                               Indie pop                      The Lumineers
# 8                                   Indie                       Taylor Swift
# 9              Hip hop, R&B, Indie, Rock,                  Tyler The Creator
# 10                                    Pop                       Taylor Swift
# ..                                    ...                                ...
# 950                                   rap                        purity ring
# 955                                   sad                           Lana Ray
# 956                                   Rap                              Drake
# 959   Everything (pop, R&B, rap, country)                      Taylor Swift
# 961                                  Jazz                                 Ye
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 1                                  YouTube                        I-N-I
# 4                                 Snapchat                          INI
# 8                                Instagram                        I-N-I
# 9                                        X                        I-N-I
# 10                                  TikTok                          INI
# ..                                     ...                          ...
# 950                              INStagram                          INI
# 955                                    ins                        I-N-N
# 956                                      X                        I-N-I
# 959                                Tiktok                        I-N-I!
# 961                                     QQ                         illi
#
#     What is your favorite game to play (either video game or IRL)?  \
# 1                                             Factorio
# 4                                           Basketball
# 8                                                  Uno
# 9                                           Basketball
# 10                                    Capture the Flag
# ..                                                 ...
# 950                                              Chess
# 955                                           valorant
# 956                                          Valorant
# 959                                   Street Fighters
# 961                                     Clash of clans
#
#     What is your dream vacation location?
# 1                               Mountains
# 4                              Australia
# 8                                  Taiwan
# 9                                    Asia
# 10                                  Spain
# ..                                    ...
# 950                            California
# 955                               finland
# 956                                Greece
# 959                               Greece
# 961                               Iceland
#
# [315 rows x 178 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df1_treatment' in vars() ), "You do not have a DataFrame called `df1_treatment`."
assert( 'df1_control' in vars() ), "You do not have a DataFrame called `df1_control`."
assert( len(df[ df.index.isin(df1_treatment.index) & df.index.isin(df1_control.index) ]) == 0), "The `df1_treatment` and `df1_control` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df1_treatment.index) & df.index.isin(df2.index) ]) == 0), "The `df1_treatment` and `df2` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df1_control.index) & df.index.isin(df2.index) ]) == 0), "The `df1_control` and `df2` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 3.3:
#
# Create a `df2_treatment` group that contains a random selection of 50% of the rows from `df2`.

# %%
df2_treatment = df2.sample(frac=.5)
df2_treatment
# Out:
#         Name Section Does your NetID ending with odd number or even number?  \
# 813     Erol     Y07                     NetID ends with an even number
# 277  Stanley     Y32                     NetID ends with an even number
# 759     Tony     Y17                      NetID ends with an odd number
# 197    Ethan     Y19                     NetID ends with an even number
# 387  Xuanhui     Y17                      NetID ends with an odd number
# ..       ...     ...                                                ...
# 79     aryan     Y10                     NetID ends with an even number
# 190    Yejee     Y25                     NetID ends with an even number
# 471  Tiffany     Y15                     NetID ends with an even number
# 420  Brendan     Y24                      NetID ends with an odd number
# 659    Jerry     Y31                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 813                                              Heads
# 277                                              Heads
# 759                                              Tails
# 197                                              Heads
# 387                                              Tails
# ..                                                 ...
# 79                                               Heads
# 190                                              Tails
# 471                                              Heads
# 420                                              Heads
# 659                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 813                               Tacos                    1.0
# 277                              Donuts                    0.0
# 759                              Donuts                    1.0
# 197                              Donuts                    1.0
# 387                               Tacos                    0.0
# ..                                  ...                    ...
# 79                               Donuts                    0.0
# 190                               Tacos                    1.0
# 471                               Tacos                    1.0
# 420                               Tacos                    0.0
# 659                               Tacos                    0.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 813                 Not a Freshman                       Morning Person
# 277            Freshman in College                         Night Person
# 759                 Not a Freshman                         Night Person
# 197            Freshman in College                         Night Person
# 387            Freshman in College                         Night Person
# ..                             ...                                  ...
# 79             Freshman in College                         Night Person
# 190            Freshman in College                       Morning Person
# 471                 Not a Freshman                         Night Person
# 420            Freshman in College                         Night Person
# 659            Freshman in College                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 813                          Afternoon Person
# 277                          Afternoon Person
# 759                          Afternoon Person
# 197                          Afternoon Person
# 387                          Afternoon Person
# ..                                        ...
# 79                           Afternoon Person
# 190                            Morning Person
# 471                          Afternoon Person
# 420                          Afternoon Person
# 659                          Afternoon Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 813                                         Illinois  ...
# 277                                     Out-of-state  ...
# 759                                     Out-of-state  ...
# 197                                         Illinois  ...
# 387                                     Out-of-state  ...
# ..                                               ...  ...
# 79                                          Illinois  ...
# 190                                         Illinois  ...
# 471                                         Illinois  ...
# 420                                         Illinois  ...
# 659                                         Illinois  ...
#
#     From 1 to 10, how happy are you right now?  \
# 813                                        7.0
# 277                                        7.0
# 759                                        4.0
# 197                                        6.8
# 387                                        7.0
# ..                                         ...
# 79                                         8.0
# 190                                        8.0
# 471                                        6.0
# 420                                        3.0
# 659                                        6.0
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 813                                               Mild
# 277                                               mild
# 759                                           moderate
# 197                                           moderate
# 387                                                NaN
# ..                                                 ...
# 79                                              Strong
# 190                                               mild
# 471                                            extreme
# 420                                             Strong
# 659                                               mild
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 813                                           I-School
# 277                                                LAS
# 759                                            iSchool
# 197                                                LAS
# 387                                               Gies
# ..                                                 ...
# 79                                                Gies
# 190                            International Relations
# 471                                            IS + CS
# 420                               Finance+Data Science
# 659                                                 IS
#
#     What do you think is the hardest major at UIUC?  \
# 813                            Computer Engineering
# 277                            Chemical Engineering
# 759                             Nuclear Engineering
# 197                            computer engineering
# 387                                              CS
# ..                                              ...
# 79                                 Computer Science
# 190              Every major has its own challenges
# 471                                    Pre - Health
# 420                            Chemical Engineering
# 659                                              CS
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 813                                   Rap                         Kanye West
# 277                                   Pop                          Ice Spice
# 759                                   CCM                    Hillsong United
# 197                             indie pop                               Joji
# 387                                   R&B                       Taylor Swift
# ..                                    ...                                ...
# 79                                    Rap                              Drake
# 190                                 Indie                                SZA
# 471                     Hip Hop, R&B, Pop                                SZA
# 420                              Pop Rock                  The Goo Goo Dolls
# 659                                  jazz                             taylor
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 813                               Snapchat                          INI
# 277                                Discord                          INI
# 759                              Instagram                        I-N-I
# 197                              Instagram                        I-N-I
# 387                                Tiktoik                          NaN
# ..                                     ...                          ...
# 79                                Snapchat                          INI
# 190                                 tiktok                          INI
# 471                                 Tiktok                          ini
# 420                              Instagram                        I-N-I
# 659                                  zenly                         rest
#
#     What is your favorite game to play (either video game or IRL)?  \
# 813                          Super Smash Bros Ultimate
# 277                                         Brawlstars
# 759                                     Genshin Impact
# 197                                             soccer
# 387                                                NaN
# ..                                                 ...
# 79                                       Truth or dare
# 190                                             spoons
# 471                                       Boomerang Fu
# 420                                         Ice Hockey
# 659                                                LOL
#
#     What is your dream vacation location?
# 813                               Bahamas
# 277                                Hawaii
# 759                              Maldives
# 197                               Vietnam
# 387                                 Tokyo
# ..                                    ...
# 79                                   Bali
# 190                          Cocos Island
# 471                             Bora Bora
# 420                             Santorini
# 659                                 japan
#
# [163 rows x 178 columns]

# %% [markdown]
# ## Part 3.4:
#
# Create a `df2_control` group that contains the other half of the rows from `df2`.

# %%
df2_control = df2[ ~df2.index.isin(df2_treatment.index) ]
df2_control
# Out:
#            Name Section  \
# 3      Annabel      Y05
# 7    Joseph Kim     Y16
# 15      Michael     Y03
# 16       binchi     Y35
# 22      Justin      Y11
# ..          ...     ...
# 939       Riley    Y107
# 949    Vihaansh     Y08
# 952        Erin     Y29
# 957     Arseniy     Y20
# 962       Nyssa     Y23
#
#     Does your NetID ending with odd number or even number?  \
# 3                       NetID ends with an even number
# 7                       NetID ends with an even number
# 15                      NetID ends with an even number
# 16                       NetID ends with an odd number
# 22                      NetID ends with an even number
# ..                                                 ...
# 939                     NetID ends with an even number
# 949                      NetID ends with an odd number
# 952                      NetID ends with an odd number
# 957                                                NaN
# 962                      NetID ends with an odd number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 3                                                Heads
# 7                                                Heads
# 15                                               Heads
# 16                                               Tails
# 22                                               Heads
# ..                                                 ...
# 939                                              Tails
# 949                                              Heads
# 952                                              Heads
# 957                                              Heads
# 962                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 3                                 Tacos                    0.0
# 7                                Donuts                    1.0
# 15                                Tacos                    0.0
# 16                                Tacos                    0.0
# 22                                Tacos                    1.0
# ..                                  ...                    ...
# 939                               Tacos                    0.0
# 949                               Tacos                    1.0
# 952                               Tacos                    1.0
# 957                               Tacos                    1.0
# 962                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 3                   Not a Freshman                         Night Person
# 7                   Not a Freshman                         Night Person
# 15                  Not a Freshman                         Night Person
# 16             Freshman in College                       Morning Person
# 22                  Not a Freshman                       Morning Person
# ..                             ...                                  ...
# 939            Freshman in College                         Night Person
# 949                 Not a Freshman                         Night Person
# 952            Freshman in College                       Morning Person
# 957                 Not a Freshman                         Night Person
# 962            Freshman in College                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 3                            Afternoon Person
# 7                            Afternoon Person
# 15                           Afternoon Person
# 16                             Morning Person
# 22                           Afternoon Person
# ..                                        ...
# 939                          Afternoon Person
# 949                          Afternoon Person
# 952                          Afternoon Person
# 957                          Afternoon Person
# 962                          Afternoon Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 3                                           Illinois  ...
# 7                                           Illinois  ...
# 15                                          Illinois  ...
# 16                                      Out-of-state  ...
# 22                                          Illinois  ...
# ..                                               ...  ...
# 939                                         Illinois  ...
# 949                                     Out-of-state  ...
# 952                                         Illinois  ...
# 957                                     Out-of-state  ...
# 962                                         Illinois  ...
#
#     From 1 to 10, how happy are you right now?  \
# 3                                          5.0
# 7                                          4.0
# 15                                        10.0
# 16                                         9.2
# 22                                         8.0
# ..                                         ...
# 939                                        7.0
# 949                                        7.0
# 952                                        6.0
# 957                                        7.0
# 962                                        8.0
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 3                                             Moderate
# 7                                                 Mild
# 15                                             Extreme
# 16                                                mild
# 22                                             Strong
# ..                                                 ...
# 939                                           moderate
# 949                                            Extreme
# 952                                             strong
# 957                                           moderate
# 962                                               mild
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 3                                     ISchool and LAS
# 7                                                  LAS
# 15                                                 LAS
# 16                                                math
# 22                                            Ischool
# ..                                                 ...
# 939                                                las
# 949                               Computer Engineering
# 952                                               UIUC
# 957                                                NaN
# 962                                                las
#
#     What do you think is the hardest major at UIUC?  \
# 3                                 Computer science
# 7                                  Computer Science
# 15                           Electrical Engineering
# 16                                             math
# 22                            Chemical engineering
# ..                                              ...
# 939                                       chemistry
# 949                          Electrical Engineering
# 952                                              CS
# 957                                             NaN
# 962                                             ece
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 3                              Rap or r&b                            Eminem
# 7                              soundtrack             Ski Mask the Slump God
# 15                             Indie rock                           Pavement
# 16                                    R&B                                jay
# 22                                Hip-Hop                     Playboi Carti
# ..                                    ...                                ...
# 939                           rap and pop                              drake
# 949                                  Rock                             Eminem
# 952          R&B, Indie music, pop, K-pop                       Shawn Mendes
# 957                                   NaN                                NaN
# 962                                   pop                       taylor swift
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 3                                Snapchat                           INI
# 7                                Instagram                    I-N-O-I-S
# 15                               Instagram                        I-N-I
# 16                                     ins                          ini
# 22                              Instagram                         I-N-I
# ..                                     ...                          ...
# 939                                  insta                          INI
# 949                              Instagram                        I-N-I
# 952                              instagram                        I-N-I
# 957                                    NaN                        I-N-I
# 962                                twitter                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 3                             Volleyball or fortnight
# 7    Super Smash Bros. Ultimate (Dear Karle and Wad...
# 15                                            Baseball
# 16                                                FIFA
# 22                                      Resident Evil
# ..                                                 ...
# 939                                 egyptian rat screw
# 949                                             Soccer
# 952                                                IRL
# 957                                                NaN
# 962                                         code names
#
#     What is your dream vacation location?
# 3                                 Greece
# 7                                 Nowhere
# 15                                 France
# 16                                     LA
# 22                                  Bali
# ..                                    ...
# 939                              thaliand
# 949                                Norway
# 952                              New York
# 957                        Moscow, Russia
# 962                                greece
#
# [163 rows x 178 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df2_treatment' in vars() ), "You do not have a DataFrame called `df2_treatment`."
assert( 'df2_control' in vars() ), "You do not have a DataFrame called `df2_control`."
assert( len(df[ df.index.isin(df2_treatment.index) & df.index.isin(df2_control.index) ]) == 0), "The `df2_treatment` and `df2_control` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df2_treatment.index) & df.index.isin(df1.index) ]) == 0), "The `df2_treatment` and `df1` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df2_control.index) & df.index.isin(df1.index) ]) == 0), "The `df2_control` and `df1` groups have some overlap!  There must be no overlap."


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 3.5:
#
# Finally, read the guide: **Combining DataFrames by Concatenation** (https://discovery.cs.illinois.edu/guides/Combining-DataFrames/Combining-DataFrames-by-Concatenation/) to learn how to combine `df1_treatment` and `df2_treatment` together into one group called `treatment`.
#
# FYI, you will not need to reset the index here!

# %%
treatment = pd.concat([df1_treatment, df2_treatment])
treatment
# Out:
#                        Name Section  \
# 902                    Tony     Y35
# 181        Pranav Penaganti     Y13
# 144                 Xiaolin     Y02
# 897                   Rahil     Y08
# 595  Karle from Section Y23     Y23
# ..                      ...     ...
# 79                    aryan     Y10
# 190                   Yejee     Y25
# 471                 Tiffany     Y15
# 420                 Brendan     Y24
# 659                   Jerry     Y31
#
#     Does your NetID ending with odd number or even number?  \
# 902                      NetID ends with an odd number
# 181                      NetID ends with an odd number
# 144                      NetID ends with an odd number
# 897                      NetID ends with an odd number
# 595                     NetID ends with an even number
# ..                                                 ...
# 79                      NetID ends with an even number
# 190                     NetID ends with an even number
# 471                     NetID ends with an even number
# 420                      NetID ends with an odd number
# 659                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 902                                              Heads
# 181                                              Tails
# 144                                              Heads
# 897                                              Tails
# 595                                              Heads
# ..                                                 ...
# 79                                               Heads
# 190                                              Tails
# 471                                              Heads
# 420                                              Heads
# 659                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 902                              Donuts                    1.0
# 181                              Donuts                    1.0
# 144                              Donuts                    1.0
# 897                              Donuts                    0.0
# 595                              Donuts                    1.0
# ..                                  ...                    ...
# 79                               Donuts                    0.0
# 190                               Tacos                    1.0
# 471                               Tacos                    1.0
# 420                               Tacos                    0.0
# 659                               Tacos                    0.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 902                 Not a Freshman                         Night Person
# 181                 Not a Freshman                         Night Person
# 144                 Not a Freshman                       Morning Person
# 897            Freshman in College                         Night Person
# 595            Freshman in College                         Night Person
# ..                             ...                                  ...
# 79             Freshman in College                         Night Person
# 190            Freshman in College                       Morning Person
# 471                 Not a Freshman                         Night Person
# 420            Freshman in College                         Night Person
# 659            Freshman in College                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 902                          Afternoon Person
# 181                          Afternoon Person
# 144                            Morning Person
# 897                            Morning Person
# 595                          Afternoon Person
# ..                                        ...
# 79                           Afternoon Person
# 190                            Morning Person
# 471                          Afternoon Person
# 420                          Afternoon Person
# 659                          Afternoon Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 902                                     Out-of-state  ...
# 181                                     Out-of-state  ...
# 144                                         Illinois  ...
# 897                                     Out-of-state  ...
# 595                                     Out-of-state  ...
# ..                                               ...  ...
# 79                                          Illinois  ...
# 190                                         Illinois  ...
# 471                                         Illinois  ...
# 420                                         Illinois  ...
# 659                                         Illinois  ...
#
#     From 1 to 10, how happy are you right now?  \
# 902                                        3.0
# 181                                        3.0
# 144                                        8.0
# 897                                        9.0
# 595                                        7.0
# ..                                         ...
# 79                                         8.0
# 190                                        8.0
# 471                                        6.0
# 420                                        3.0
# 659                                        6.0
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 902                                               mild
# 181                                           Moderate
# 144                                           moderate
# 897                                            extreme
# 595                                            extreme
# ..                                                 ...
# 79                                              Strong
# 190                                               mild
# 471                                            extreme
# 420                                             Strong
# 659                                               mild
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 902                           Gies college of Business
# 181                               Grainger Engineering
# 144                                         Psychology
# 897                                            iSchool
# 595                                               Gies
# ..                                                 ...
# 79                                                Gies
# 190                            International Relations
# 471                                            IS + CS
# 420                               Finance+Data Science
# 659                                                 IS
#
#     What do you think is the hardest major at UIUC?  \
# 902                                              CS
# 181                            Computer Engineering
# 144                                     Engineering
# 897                                              CS
# 595                                              CS
# ..                                              ...
# 79                                 Computer Science
# 190              Every major has its own challenges
# 471                                    Pre - Health
# 420                            Chemical Engineering
# 659                                              CS
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 902                        popular music                            Jay Chou
# 181                       Rap/Pop/Country                               Yeat
# 144                                   Pop                          BLACKPINK
# 897                                   rap                           Kid Cudi
# 595         All honestly except for K-pop                                NaN
# ..                                    ...                                ...
# 79                                    Rap                              Drake
# 190                                 Indie                                SZA
# 471                     Hip Hop, R&B, Pop                                SZA
# 420                              Pop Rock                  The Goo Goo Dolls
# 659                                  jazz                             taylor
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 902                              Instagram                   No respond
# 181                              Instagram                          INI
# 144                                Spotify                     Illinois
# 897                                      X                        i n i
# 595                                 BeReal                        I-N-I
# ..                                     ...                          ...
# 79                                Snapchat                          INI
# 190                                 tiktok                          INI
# 471                                 Tiktok                          ini
# 420                              Instagram                        I-N-I
# 659                                  zenly                         rest
#
#     What is your favorite game to play (either video game or IRL)?  \
# 902                                          Minecraft
# 181                                                GTA
# 144                              Honor of Kings: World
# 897                                               fifa
# 595                                               Ludo
# ..                                                 ...
# 79                                       Truth or dare
# 190                                             spoons
# 471                                       Boomerang Fu
# 420                                         Ice Hockey
# 659                                                LOL
#
#     What is your dream vacation location?
# 902                                Bahama
# 181                                 Ibiza
# 144                                 China
# 897                                 India
# 595                                 Italy
# ..                                    ...
# 79                                   Bali
# 190                          Cocos Island
# 471                             Bora Bora
# 420                             Santorini
# 659                                 japan
#
# [477 rows x 178 columns]

# %% [markdown]
# ## Part 3.6:
#
# Using the same technique, combine `df1_control` and `df2_control` together into one group called `control`:

# %%
control = pd.concat([df1_control, df2_control])
control
# Out:
#                 Name Section  \
# 1         Prof. Wade  L1, L2
# 4             Ayden      Y14
# 8              Sarah     Y36
# 9    Pradnyan Khodke     Y24
# 10           Aaliyah     Y13
# ..               ...     ...
# 939            Riley    Y107
# 949         Vihaansh     Y08
# 952             Erin     Y29
# 957          Arseniy     Y20
# 962            Nyssa     Y23
#
#     Does your NetID ending with odd number or even number?  \
# 1                                                  NaN
# 4                       NetID ends with an even number
# 8                        NetID ends with an odd number
# 9                        NetID ends with an odd number
# 10                      NetID ends with an even number
# ..                                                 ...
# 939                     NetID ends with an even number
# 949                      NetID ends with an odd number
# 952                      NetID ends with an odd number
# 957                                                NaN
# 962                      NetID ends with an odd number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 1                                                Heads
# 4                                                Heads
# 8                                                Heads
# 9                                                Heads
# 10                                               Heads
# ..                                                 ...
# 939                                              Tails
# 949                                              Heads
# 952                                              Heads
# 957                                              Heads
# 962                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 1                                 Tacos                    1.0
# 4                                Donuts                    1.0
# 8                                Donuts                    0.0
# 9                                 Tacos                    1.0
# 10                               Donuts                    1.0
# ..                                  ...                    ...
# 939                               Tacos                    0.0
# 949                               Tacos                    1.0
# 952                               Tacos                    1.0
# 957                               Tacos                    1.0
# 962                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 1                   Not a Freshman                         Night Person
# 4              Freshman in College                         Night Person
# 8              Freshman in College                       Morning Person
# 9                   Not a Freshman                       Morning Person
# 10             Freshman in College                         Night Person
# ..                             ...                                  ...
# 939            Freshman in College                         Night Person
# 949                 Not a Freshman                         Night Person
# 952            Freshman in College                       Morning Person
# 957                 Not a Freshman                         Night Person
# 962            Freshman in College                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 1                            Afternoon Person
# 4                              Morning Person
# 8                              Morning Person
# 9                              Morning Person
# 10                           Afternoon Person
# ..                                        ...
# 939                          Afternoon Person
# 949                          Afternoon Person
# 952                          Afternoon Person
# 957                          Afternoon Person
# 962                          Afternoon Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 1                                                NaN  ...
# 4                                           Illinois  ...
# 8                                           Illinois  ...
# 9                                           Illinois  ...
# 10                                          Illinois  ...
# ..                                               ...  ...
# 939                                         Illinois  ...
# 949                                     Out-of-state  ...
# 952                                         Illinois  ...
# 957                                     Out-of-state  ...
# 962                                         Illinois  ...
#
#     From 1 to 10, how happy are you right now?  \
# 1                                         8.25
# 4                                         8.00
# 8                                         7.00
# 9                                         5.00
# 10                                        8.00
# ..                                         ...
# 939                                       7.00
# 949                                       7.00
# 952                                       6.00
# 957                                       7.00
# 962                                       8.00
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 1                                             Moderate
# 4                                               Strong
# 8                                               Strong
# 9                                               Strong
# 10                                             Extreme
# ..                                                 ...
# 939                                           moderate
# 949                                            Extreme
# 952                                             strong
# 957                                           moderate
# 962                                               mild
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 1                                             Grainger
# 4                                                 Gies
# 8                                              iSchool
# 9                                                  LAS
# 10                                             iSchool
# ..                                                 ...
# 939                                                las
# 949                               Computer Engineering
# 952                                               UIUC
# 957                                                NaN
# 962                                                las
#
#     What do you think is the hardest major at UIUC?  \
# 1                                           Physics
# 4                                   Any engineering
# 8                                  Computer Science
# 9                                               ECE
# 10                                 Computer Science
# ..                                              ...
# 939                                       chemistry
# 949                          Electrical Engineering
# 952                                              CS
# 957                                             NaN
# 962                                             ece
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 1                             Pop and EDM                       Taylor Swift
# 4                               Indie pop                      The Lumineers
# 8                                   Indie                       Taylor Swift
# 9              Hip hop, R&B, Indie, Rock,                  Tyler The Creator
# 10                                    Pop                       Taylor Swift
# ..                                    ...                                ...
# 939                           rap and pop                              drake
# 949                                  Rock                             Eminem
# 952          R&B, Indie music, pop, K-pop                       Shawn Mendes
# 957                                   NaN                                NaN
# 962                                   pop                       taylor swift
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 1                                  YouTube                        I-N-I
# 4                                 Snapchat                          INI
# 8                                Instagram                        I-N-I
# 9                                        X                        I-N-I
# 10                                  TikTok                          INI
# ..                                     ...                          ...
# 939                                  insta                          INI
# 949                              Instagram                        I-N-I
# 952                              instagram                        I-N-I
# 957                                    NaN                        I-N-I
# 962                                twitter                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 1                                             Factorio
# 4                                           Basketball
# 8                                                  Uno
# 9                                           Basketball
# 10                                    Capture the Flag
# ..                                                 ...
# 939                                 egyptian rat screw
# 949                                             Soccer
# 952                                                IRL
# 957                                                NaN
# 962                                         code names
#
#     What is your dream vacation location?
# 1                               Mountains
# 4                              Australia
# 8                                  Taiwan
# 9                                    Asia
# 10                                  Spain
# ..                                    ...
# 939                              thaliand
# 949                                Norway
# 952                              New York
# 957                        Moscow, Russia
# 962                                greece
#
# [478 rows x 178 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Analysis: Blocking

# %% [markdown]
# **Q: In your own words, explain what blocking is and why it is useful to someone who has never taken a statistics course before! You can use what you did above as an example in your explanation if you'd like. Make sure to include what blocking is and why it is useful. Write at least three complete sentences to answer this question.**

# %% [markdown]
# Blocking is often performed in experiments with small sample sizes when researchers place subjects that are in similar groups and then decide who gets what treatment within that group. This simplifies the data and eliminates any bias that may occur in the sampling process. Blocking also allows the treatment and control groups to be balanced, making the results as useful as possible.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
