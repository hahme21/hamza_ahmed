# %% [markdown]
# # STAT 207 Homework 4 [25 points]
#
# ## Populations, Samples, and Summarizing Data

# %% [markdown]
# Due: Friday, February 16, end of day (11:59 pm CT)
#
# <hr>

# %% [markdown]
# ## Python Component
#
# Run the following code chunk to import the packages needed for this assignment:
#
# - pandas
# - matplotlib.pyplot
# - seaborn
#
# The first package assists in analyzing a dataset.  The second two packages provide support for visualizations.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ## 1. Read in the Data [0.5 points]
#
# The Super Bowl is one of the biggest events for ads in addition to for the NFL.  Information about ads for the top 10 brands that advertise at the Superbowl are included in the superbowl_ads.csv file.  You can read a little more about this data in a FiveThirtyEight article (https://projects.fivethirtyeight.com/super-bowl-ads/).
#
# Read this file in.  No need to drop any missing values.
#
# You may also want to explore the data to determine how it relates to a population and/or the representativeness of the data.

# %%
df = pd.read_csv('superbowl_ads.csv')
df
# Out:
#      year      brand                          superbowl_ads_dot_com_url  \
# 0    2018     Toyota        https://superbowl-ads.com/good-odds-toyota/
# 1    2020  Bud Light  https://superbowl-ads.com/2020-bud-light-seltz...
# 2    2006  Bud Light  https://superbowl-ads.com/2006-bud-light-bear-...
# 3    2018    Hynudai  https://superbowl-ads.com/hope-detector-nfl-su...
# 4    2003  Bud Light  https://superbowl-ads.com/2003-bud-light-hermi...
# ..    ...        ...                                                ...
# 242  2014        NFL                 https://superbowl-ads.com/nfl-now/
# 243  2012  Budweiser  https://superbowl-ads.com/2012-budweiser-etern...
# 244  2001      Pepsi  https://superbowl-ads.com/2001-pepsi-kasparov-...
# 245  2001    E-Trade  https://superbowl-ads.com/2001-etrade-security...
# 246  2001  Budweiser    https://superbowl-ads.com/2001-budweiser-nsync/
#
#                                      youtube_url  funny  show_product_quickly  \
# 0    https://www.youtube.com/watch?v=zeBZvwYQ-hA  False                 False
# 1    https://www.youtube.com/watch?v=nbbp0VW7z8w   True                  True
# 2    https://www.youtube.com/watch?v=yk0MQD5YgV8   True                 False
# 3    https://www.youtube.com/watch?v=lNPccrGk77A  False                  True
# 4    https://www.youtube.com/watch?v=ovQYgnXHooY   True                  True
# ..                                           ...    ...                   ...
# 242                                          NaN  False                  True
# 243  https://www.youtube.com/watch?v=_GeiOdHsW_8  False                  True
# 244  https://www.youtube.com/watch?v=pldGc0Cpf84   True                 False
# 245  https://www.youtube.com/watch?v=39BL7iqe6pQ   True                 False
# 246  https://www.youtube.com/watch?v=H9YdunAo3Ug  False                 False
#
#      patriotic  celebrity  danger  animals  ...  like_count dislike_count  \
# 0        False      False   False    False  ...      1233.0          38.0
# 1        False       True    True    False  ...       485.0          14.0
# 2        False      False    True     True  ...       129.0          15.0
# 3        False      False   False    False  ...         2.0           0.0
# 4        False      False    True     True  ...        20.0           3.0
# ..         ...        ...     ...      ...  ...         ...           ...
# 242      False      False   False    False  ...         NaN           NaN
# 243       True      False   False     True  ...       572.0         100.0
# 244      False       True    True    False  ...        14.0           0.0
# 245      False      False    True    False  ...        12.0           4.0
# 246      False       True   False    False  ...       334.0           4.0
#
#     favorite_count comment_count          published_at  \
# 0              0.0           NaN  2018-02-03T11:29:14Z
# 1              0.0          14.0  2020-01-31T21:04:13Z
# 2              0.0           9.0  2006-02-06T10:02:36Z
# 3              0.0           0.0  2018-03-09T15:40:18Z
# 4              0.0           2.0  2006-07-18T04:53:42Z
# ..             ...           ...                   ...
# 242            NaN           NaN                   NaN
# 243            0.0         271.0  2012-02-05T03:27:52Z
# 244            0.0           2.0  2012-09-08T19:53:53Z
# 245            0.0           3.0  2008-01-11T18:18:39Z
# 246            0.0          71.0  2007-12-14T23:33:27Z
#
#                                                  title  \
# 0          Toyota Super Bowl Commercial 2018 Good Odds
# 1    Bud Light: Post Malone #PostyStore Inside Post...
# 2           Super Bowl 2006: Bud Light "Save Yourself"
# 3                       Hyundai / Hope Detector (2018)
# 4                                    bud light pick up
# ..                                                 ...
# 242                                                NaN
# 243  The Cult " She Sells Sanctuary" - Budweiser: '...
# 244  Pepsi - Chessmaster Garry Kasparov Super Bowl ...
# 245                         ETrade Commercial - Matrix
# 246                       NSync - Budweiser Commercial
#
#                                            description  \
# 0    Toyota Super Bowl Commercial 2018 Good Odds. Y...
# 1    Bud Light, Post Malone "#PostyStore Inside Pos...
# 2    Bud Light Super Bowl commercial where two guys...
# 3    TV or Web Commercial,  shot on location in MN ...
# 4    see how a dude tries to pick up babes at a bea...
# ..                                                 ...
# 242                                                NaN
# 243  Budweiser Super Bowl Commercial 2012\r\nMash-u...
# 244
# 245  Commercial from 2001 for ETrade featuring an a...
# 246         The 5 guys in an anti-drinking commercial.
#
#                                             thumbnail      channel_title  \
# 0    https://i.ytimg.com/vi/zeBZvwYQ-hA/sddefault.jpg  Funny Commercials
# 1    https://i.ytimg.com/vi/nbbp0VW7z8w/sddefault.jpg    VCU Brandcenter
# 2                                                 NaN       John Keehler
# 3                                                 NaN          IATSE 490
# 4                                                 NaN           jassymei
# ..                                                ...                ...
# 242                                               NaN                NaN
# 243  https://i.ytimg.com/vi/_GeiOdHsW_8/sddefault.jpg      TheCULTFamily
# 244                                               NaN             Rtrt67
# 245                                               NaN          edgesmash
# 246                                               NaN       thesilverd0e
#
#     category_id
# 0           1.0
# 1          27.0
# 2          17.0
# 3          22.0
# 4          24.0
# ..          ...
# 242         NaN
# 243        10.0
# 244        24.0
# 245        23.0
# 246        24.0
#
# [247 rows x 25 columns]

# %%
df.dtypes
# Out:
# year                           int64
# brand                         object
# superbowl_ads_dot_com_url     object
# youtube_url                   object
# funny                           bool
# show_product_quickly            bool
# patriotic                       bool
# celebrity                       bool
# danger                          bool
# animals                         bool
# use_sex                         bool
# id                            object
# kind                          object
# etag                          object
# view_count                   float64
# like_count                   float64
# dislike_count                float64
# favorite_count               float64
# comment_count                float64
# published_at                  object
# title                         object
# description                   object
# thumbnail                     object
# channel_title                 object
# category_id                  float64
# dtype: object

# %%
df.describe()
# Out:
#               year    view_count     like_count  dislike_count  \
# count   247.000000  2.310000e+02     225.000000     225.000000
# mean   2010.190283  1.407556e+06    4146.031111     833.537778
# std       5.860872  1.197111e+07   23920.402935    6948.521873
# min    2000.000000  1.000000e+01       0.000000       0.000000
# 25%    2005.000000  6.431000e+03      19.000000       1.000000
# 50%    2010.000000  4.137900e+04     130.000000       7.000000
# 75%    2015.000000  1.700155e+05     527.000000      24.000000
# max    2020.000000  1.763734e+08  275362.000000   92990.000000
#
#        favorite_count  comment_count  category_id
# count           231.0      222.00000   231.000000
# mean              0.0      188.63964    19.316017
# std               0.0      986.45691     8.004328
# min               0.0        0.00000     1.000000
# 25%               0.0        1.00000    17.000000
# 50%               0.0       10.00000    23.000000
# 75%               0.0       50.75000    24.000000
# max               0.0     9190.00000    29.000000

# %% [markdown]
# ## 2. Two Way Tables [1 point]

# %% [markdown]
# Generate two-way tables needed to compare the distributions between brands and ads including animals.

# %%
df['animals'].value_counts()
# Out:
# animals
# False    155
# True      92
# Name: count, dtype: int64

# %%
pd.crosstab(df['animals'],df['brand'])
# Out:
# brand    Bud Light  Budweiser  Coca-Cola  Doritos  E-Trade  Hynudai  Kia  NFL  \
# animals
# False           39         19          9       15        9       15    8   11
# True            24         24         12       10        4        7    5    0
#
# brand    Pepsi  Toyota
# animals
# False       22       8
# True         3       3

# %% [markdown]
# ## 3. Understanding Missing Data [1.5 points]
#
# **a)** How many missing values are recorded for each variable?

# %%
df.isna().sum()
# Out:
# year                           0
# brand                          0
# superbowl_ads_dot_com_url      0
# youtube_url                   11
# funny                          0
# show_product_quickly           0
# patriotic                      0
# celebrity                      0
# danger                         0
# animals                        0
# use_sex                        0
# id                            11
# kind                          16
# etag                          16
# view_count                    16
# like_count                    22
# dislike_count                 22
# favorite_count                16
# comment_count                 25
# published_at                  16
# title                         16
# description                   40
# thumbnail                    129
# channel_title                 16
# category_id                   16
# dtype: int64

# %% [markdown]
# **b)** First, make a new variable in the data that records whether the comment count is missing.
#
# Then, count the number of missing values in the comments variable for each brand.  Do this second part in one line of code for full credit.

# %%
df['comment count missing'] = df['comment_count'].isna() == True
df.groupby('brand')['comment count missing'].agg('sum').reset_index()
# Out:
#        brand  comment count missing
# 0  Bud Light                      5
# 1  Budweiser                      5
# 2  Coca-Cola                      1
# 3    Doritos                      3
# 4    E-Trade                      3
# 5    Hynudai                      1
# 6        Kia                      2
# 7        NFL                      2
# 8      Pepsi                      1
# 9     Toyota                      2

# %% [markdown]
# ## 4. Exploring Comments [2 points]
#
# Generate numerical summaries and graphical visualizations for the comments variable based on whether an ad includes a celebrity.

# %%
sns.violinplot(x='celebrity',y='comment_count',data=df)
# Out:
# <Axes: xlabel='celebrity', ylabel='comment_count'>

# %%
df[['comment_count','celebrity']].groupby('celebrity').describe()
# Out:
#           comment_count
#                   count        mean          std  min  25%   50%   75%     max
# celebrity
# False             155.0  167.683871   955.937296  0.0  1.0   9.0  42.0  9190.0
# True               67.0  237.119403  1059.597344  0.0  1.0  14.0  68.0  8441.0

# %% [markdown]
# ## 5. View Counts [2.5 points]
#
# **a)** Generate a histogram of the view counts in the data.

# %%
df['view_count'].hist()
# Out:
# <Axes: >

# %%
df['view_count'].median()
# Out:
# 41379.0

# %%
df['view_count'].describe()
# Out:
# count    2.310000e+02
# mean     1.407556e+06
# std      1.197111e+07
# min      1.000000e+01
# 25%      6.431000e+03
# 50%      4.137900e+04
# 75%      1.700155e+05
# max      1.763734e+08
# Name: view_count, dtype: float64

# %% [markdown]
# **b)** Take a random sample of 40 ads from the data.  Then explore the distribution of view counts for your random sample with at least one of numerical summaries or graphical displays.

# %%
df1 = df['view_count'].sample(n=40)
df1
# Out:
# 89       14579.0
# 63     2319854.0
# 137      15776.0
# 3          198.0
# 200     286010.0
# 145     166102.0
# 21       29219.0
# 46       97247.0
# 31        5049.0
# 243     220292.0
# 120        546.0
# 210       3183.0
# 51       49339.0
# 203       6430.0
# 38        3667.0
# 80          79.0
# 184       5699.0
# 199        125.0
# 187        518.0
# 20       72997.0
# 111      85274.0
# 160      10925.0
# 118      17209.0
# 32       85454.0
# 24       36832.0
# 93         487.0
# 74        6641.0
# 173        236.0
# 175        179.0
# 237    1214968.0
# 141     403641.0
# 107      39897.0
# 68      327529.0
# 227      18670.0
# 87     4921309.0
# 55      177497.0
# 169         56.0
# 19     1990447.0
# 182      92878.0
# 244       1475.0
# Name: view_count, dtype: float64

# %%
df1.hist()
# Out:
# <Axes: >

# %% [markdown]
# Remember to keep all your cells and hit the save icon above periodically to checkpoint (save) your results on your local computer. Once you are satisified with your results restart the kernel and run all (Kernel -> Restart & Run All). **Make sure nothing has changed**. Checkpoint and exit (File -> Save and Checkpoint + File -> Close and Halt). Follow the instructions on the Homework 4 Canvas Assignment to submit your notebook to GitHub.  Be sure to also complete the Gradescope component of this assignment.
